# %% [markdown]
# # Homework 2 Code - Considering Bias in Data
#
# ## Data Analysis
# This notebook cleans the requested data and analyzes bias in online political resources by looking at Wikipedia article prevalence and quality of politicians in over 167 countries. The code produces six tables, embedded at the bottom of this notebook.
#
# 1. Top 10 countries by coverage: The 10 countries with the highest total articles per capita (in descending order) .
# 2. Bottom 10 countries by coverage: The 10 countries with the lowest total articles per capita (in ascending order) .
# 3. Top 10 countries by high quality: The 10 countries with the highest high quality articles per capita (in descending order) .
# 4. Bottom 10 countries by high quality: The 10 countries with the lowest high quality articles per capita (in ascending order).
# 5. Geographic regions by total coverage: A rank ordered list of geographic regions (in descending order) by total articles per capita.
# 6. Geographic regions by high quality coverage: Rank ordered list of geographic regions (in descending order) by high quality articles per capita.
# This homework uses example code referenced in the markdown below and in the README.
#
# ##### USER NOTE!
#
# This note in the markdowns encourages users to make customized edits to control their desired inputs and outputs. Please ctrl+F to see all user notes.

# %% [markdown]
# # Requesting ORES scores through LiftWing ML Service API
# Wikimedia Foundation (WMF) is reworking access to their APIs. It is likely in the coming years that all API access will require some kind of authentication, either through a simple key/token or through some version of OAuth. For now this is still a work in progress. You can follow the progress from their [API portal](https://api.wikimedia.org/wiki/Main_Page). Another on-going change is better control over API services in situations where those services require additional computational resources, beyond simply serving the text of a web page (i.e., the text of an article). Services like ORES that require running an ML model over the text of an article page is an example of a compute intensive API service.
#
# Wikimedia is implementing a new Machine Learning (ML) service infrastructure that they call [LiftWing](https://wikitech.wikimedia.org/wiki/Machine_Learning/LiftWing). Given that ORES already has several ML models that have been well used, ORES is the first set of APIs that are being moved to LiftWing.
#
# This example illustrates how to generate article quality estimates for article revisions using the LiftWing version of [ORES](https://www.mediawiki.org/wiki/ORES). The [ORES API documentation](https://ores.wikimedia.org) can be accessed from the main ORES page. The [ORES LiftWing documentation](https://wikitech.wikimedia.org/wiki/Machine_Learning/LiftWing/Usage) is very thin ... even thinner than the standard ORES documentation. Further, it is clear that some parameters have been renamed (e.g., "revid" in the old ORES API is now "rev_id" in the LiftWing ORES API).

# %% [markdown]
# # Loading Libraries
#
# The following code block references Dr. David W. Mcdonald's example code, with new libraries added to the originals.

# %%
# 
# These are standard python modules
import json, time, urllib.parse
#
# The 'requests' module is not a standard Python module. You will need to install this with pip/pip3 if you do not already have it
import requests
import pandas as pd
import csv
import numpy as np
from IPython.display import display

# %% [markdown]
# # Import Data
#
# Imports the extracted dictionary (a json file) of politician names ("article_title"), and revision IDs (lastrevid/rev_id) provided by Wikipedia .
#
# These article titles are  titles of Wikipedia pages about a politician, at varying degrees of completeness.
#
# The following code block references Dr. David W. Mcdonald's example code.

# %%
# Load the JSON data from the file
with open('politicians-and-revision-ids.json', 'r') as json_file:
    data = json.load(json_file)

# Create a new dictionary with 'article_title' as a string and 'rev_id' as an integer
ARTICLE_REVISIONS = {article: {'article_title': article, 'rev_id': int(info.pop('lastrevid'))} for article, info in data.items() if 'lastrevid' in info}

# Print the first five key-value pairs to check the result
for i, (key, value) in enumerate(ARTICLE_REVISIONS.items()):
    if i == 5:
        break
    print(f"{key}: {value}")
# Out:
# Abdul Baqi Turkistani: {'article_title': 'Abdul Baqi Turkistani', 'rev_id': 1231655023}
# Abdul Ghani Ghani: {'article_title': 'Abdul Ghani Ghani', 'rev_id': 1227026187}
# Abdul Rahim Ayoubi: {'article_title': 'Abdul Rahim Ayoubi', 'rev_id': 1226326055}
# Ahmad Wali Massoud: {'article_title': 'Ahmad Wali Massoud', 'rev_id': 1221720658}
# Aimal Faizi: {'article_title': 'Aimal Faizi', 'rev_id': 1185105938}

# %% [markdown]
# # Initialize Constants
#
# Establishes the API request endpoint and parameters in order to extract the pageviews.
#
# The following code block references Dr. David W. Mcdonald's example code, edited only for the specific parameters email and access token
#
# ##### USER NOTE!
# - User must change the email and Access Token in order for this code to work.

# %%
#########
#
#    CONSTANTS
#

#    The current LiftWing ORES API endpoint and prediction model
#
API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"

#
#    The throttling rate is a function of the Access token that you are granted when you request the token. The constants
#    come from dissecting the token and getting the rate limits from the granted token. An example of that is below.
#
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = ((60.0*60.0)/5000.0)-API_LATENCY_ASSUMED  # The key authorizes 5000 requests per hour

#    When making automated requests we should include something that is unique to the person making the request
#    This should include an email - your UW email would be good to put in there
#    
#    Because all LiftWing API requests require some form of authentication, you need to provide your access token
#    as part of the header too
#
REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "kilpas@uw.edu, University of Washington, MSDS DATA 512 - AUTUMN 2024",
    'Content-Type': 'application/json',
    'Authorization': "Bearer {access_token}"
}
#
#    This is a template for the parameters that we need to supply in the headers of an API request
#
REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address' : "kilas@uw.edu",         # your email address should go here
    'access_token'  : ""          # the access token you create will need to go here
}

#    This is a template of the data required as a payload when making a scoring request of the ORES model
#
ORES_REQUEST_DATA_TEMPLATE = {
    "lang":        "en",     # required that its english - we're scoring English Wikipedia revisions
    "rev_id":      "",       # this request requires a revision id
    "features":    True
}

#
#    These are used later - defined here so they, at least, have empty values
#
USERNAME = "kilpas"
ACCESS_TOKEN = ""
#

# %% [markdown]
# # Get your access token
#
# You will need a Wikimedia user account to get access to Lift Wing (the ML API service). You can either [create an account or login](https://api.wikimedia.org/w/index.php?title=Special:UserLogin). If you have a Wikipedia user account - you might already have an Wikimedia account. If you are not sure try your Wikipedia username and password to check it. If you do not have a Wikimedia account you will need to create an account that you can use to get an access token.
#
# There is [a 'guide' that describes how to get authentication tokens](https://api.wikimedia.org/wiki/Authentication) - but not everything works the way it is described in that documentation. You should review that documentation and then read the rest of this comment.
#
# The documentation talks about using a "dashboard" for managing authentication tokens. That's a rather generous description for what looks like a simple list of token things. You might have a hard time finding this "dashboard". First, on the left hand side of the page, you'll see a column of links. The bottom section is a set of links titled "Tools". In that section is a link that says [Special pages](https://api.wikimedia.org/wiki/Special:SpecialPages) which will take you to a list of ... well, special pages. At the very bottom of the "Special pages" page is a section titled "Other special pages" (scroll all the way to the bottom). The first link in that section is called [API keys](https://api.wikimedia.org/wiki/Special:AppManagement). When you get to the "API keys" page you can create a new key.
#
# The authentication guide suggests that you should create a server-side app key. This does not seem to work correctly - as yet. It failed on multiple attempts when I attempted to create a server-side app key. BUT, there is an option to create a [Personal API token](https://api.wikimedia.org/wiki/Authentication) that should work for this course and the type of ORES page scoring that you will need to perform.
#
# Note, when you create a Personal API token you are granted the three items - a Client ID, a Client secret, and a Access token - you shold save all three of these. When you dismiss the box they are gone. If you lose any one of the tokens you can destroy or deactivate the Personal API token from the dashboard and then create a new one.
#
# The value you need to work the code below is the Access token - a very long string.

# %% [markdown]
# The Wikimedia Foundation appears to be issuing access tokens that are adhering to the [JWT (JSON Web Token) standard](https://jwt.io/introduction/). There was also some documentation by IBM about the [use of JWT tokens](https://www.ibm.com/docs/en/cics-ts/6.1?topic=cics-json-web-token-jwt) that I found useful. Keep in mind, documentation from IBM is specific to their implementation of the JWT standard. Access tokens are composed of different parts that specify the domain being accessed and rate limits. The little snippet of code below is not required to make ORES requests. It just allows us to see what is in the Wikimedia provided access token that you were issued.

# %% [markdown]
# ## Define a function to make the ORES API request
#
# The API request will be made using a function to encapsulate call and make access reusable in other notebooks. The procedure is parameterized, relying on the constants above for some important default parameters. The primary assumption is that this function will be used to request data for a set of article revisions. The main parameter is 'article_revid'. One should be able to simply pass in a new article revision id on each call and get back a python dictionary as the result. A valid result will be a dictionary that contains the probabilities that the specific revision is one of six different article quality levels. Generally, quality level with the highest probability score is considered the quality level for the article. This can be tricky when you have two (or more) highly probable quality levels.

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_ores_score_per_article(article_revid = None, email_address=None, access_token=None,
                                   endpoint_url = API_ORES_LIFTWING_ENDPOINT, 
                                   model_name = API_ORES_EN_QUALITY_MODEL, 
                                   request_data = ORES_REQUEST_DATA_TEMPLATE, 
                                   header_format = REQUEST_HEADER_TEMPLATE, 
                                   header_params = REQUEST_HEADER_PARAMS_TEMPLATE):
    
    #    Make sure we have an article revision id, email and token
    #    This approach prioritizes the parameters passed in when making the call
    if article_revid:
        request_data['rev_id'] = article_revid
    if email_address:
        header_params['email_address'] = email_address
    if access_token:
        header_params['access_token'] = access_token
    
    #   Making a request requires a revision id - an email address - and the access token
    if not request_data['rev_id']:
        raise Exception("Must provide an article revision id (rev_id) to score articles")
    if not header_params['email_address']:
        raise Exception("Must provide an 'email_address' value")
    if not header_params['access_token']:
        raise Exception("Must provide an 'access_token' value")
    
    # Create the request URL with the specified model parameter - default is a article quality score request
    request_url = endpoint_url.format(model_name=model_name)
    
    # Create a compliant request header from the template and the supplied parameters
    headers = dict()
    for key in header_format.keys():
        headers[str(key)] = header_format[key].format(**header_params)
    
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free data
        # source like ORES - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        #response = requests.get(request_url, headers=headers)
        response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# **Example 1** - Call the function for one specific article title by passing in three items, revision id, email, and access token. The following code block references Dr. David W. Mcdonald's example code, edited to confirm the constants configuration and success in calling the ORES function above.

# %%
#   Which article - the key for the article dictionary defined above
article_title = "Abdul Baqi Turkistani"
#
print(f"Getting LiftWing ORES scores for '{article_title}' with revid: {ARTICLE_REVISIONS[article_title]:d}")
#
#    Make the call, just pass in the article revision ID, email address, and access token
score = request_ores_score_per_article(article_revid=ARTICLE_REVISIONS[article_title],
                                       email_address="kilpas@uw.edu",
                                       access_token=ACCESS_TOKEN)
#
#    Output the result
print(json.dumps(score,indent=4))
#
# Out:
# Getting LiftWing ORES scores for 'Abdul Baqi Turkistani' with revid: 1231655023
# {
#     "enwiki": {
#         "models": {
#             "articlequality": {
#                 "version": "0.9.2"
#             }
#         },
#         "scores": {
#             "1231655023": {
#                 "articlequality": {
#                     "score": {
#                         "prediction": "Stub",
#                         "probability": {
#                             "B": 0.007563164541978764,
#                             "C": 0.010571998067933679,
#                             "FA": 0.0014567448768872152,
#                             "GA": 0.00350824677167893,
#                             "Start": 0.04243220742433865,
#                             "Stub": 0.9344676383171826
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }

# %% [markdown]
# # Call the function to get ORES Scores for all article titles
#
# This block of code references Dr. McDonald's example code, generalized for a larger dictionary of article titles and revision IDs. The successful predictions are saved to a file titled 'politicians_final_ORES_scores.json'.
#
# The code takes approximately 4 hours to run, and outputs a list of article titles whose predictions are not available through the ORES tool. These articles will not be included in the analysis due to lacking the necessary prediction data.

# %%
# Initialize a dictionary to store the final ORES scores for all articles
final_ores_scores = {}

# Initialize a list to store article titles that failed to get an ORES score
failed_articles = []

# Iterate over all article titles and their corresponding data in ARTICLE_REVISIONS
for article_title, info in ARTICLE_REVISIONS.items():
    
    # Access the rev_id from the ARTICLE_REVISIONS dictionary
    rev_id = info['rev_id']

    # Print the message with the correct formatting for rev_id
    print(f"Getting LiftWing ORES scores for '{article_title}' with revid: {rev_id}")
    
    try:
        # Make the call, passing in the article revision ID, email address, and access token
        score = request_ores_score_per_article(article_revid=rev_id,
                                               email_address="kilpas@uw.edu",
                                               access_token=ACCESS_TOKEN)
        
        if score:  # If the score was successfully returned
            final_ores_scores[article_title] = {
                "rev_id": rev_id,
                "ores_score": score
            }
            # Output the result for debugging purposes (optional)
            # print(json.dumps(score, indent=4))
        else:
            raise ValueError("No ORES score returned.")

    except Exception as e:
        # Handle any errors (e.g., failed request, missing data, etc.)
        print(f"Error fetching ORES score for article '{article_title}' (rev_id: {rev_id}): {e}")
        failed_articles.append(article_title)  # Add the article title to the failed list
    
    # Optional: add a delay between requests if needed to avoid hitting API rate limits
    time.sleep(API_THROTTLE_WAIT)

# Save the successful ORES scores to a JSON file
with open('politicians_final_ORES_scores.json', 'w') as output_file:
    json.dump(final_ores_scores, output_file, indent=4)

# Print and save the list of articles that failed to get a score
if failed_articles:
    print("\nThe following articles failed to get an ORES score:")
    for article in failed_articles:
        print(f"- {article}")
    
    # Save the failed articles to a separate JSON file for logging purposes
    with open('failed_politicians_ORES_scores.json', 'w') as failed_file:
        json.dump(failed_articles, failed_file, indent=4)
else:
    print("\nAll articles were successfully scored.")
# Out:
# Getting LiftWing ORES scores for 'Abdul Baqi Turkistani' with revid: 1231655023
# Getting LiftWing ORES scores for 'Abdul Ghani Ghani' with revid: 1227026187
# Getting LiftWing ORES scores for 'Abdul Rahim Ayoubi' with revid: 1226326055
# Getting LiftWing ORES scores for 'Ahmad Wali Massoud' with revid: 1221720658
# Getting LiftWing ORES scores for 'Aimal Faizi' with revid: 1185105938
# Getting LiftWing ORES scores for 'Amir Muhammad Akhundzada' with revid: 1247931713
# Getting LiftWing ORES scores for 'Aziza Ahmadyar' with revid: 1195651393
# Getting LiftWing ORES scores for 'Azizullah Lodin' with revid: 1247762293
# Getting LiftWing ORES scores for 'Baran Khan Kudezai' with revid: 1176481824
# Getting LiftWing ORES scores for 'Bashir Ahmad Bezan' with revid: 1248505877
# Getting LiftWing ORES scores for 'Cheragh Ali Cheragh' with revid: 1193992206
# Getting LiftWing ORES scores for 'Ezatullah (Nangarhar)' with revid: 1158302291
# Getting LiftWing ORES scores for 'Fazel Ahmed Manawi' with revid: 1234514379
# Getting LiftWing ORES scores for 'Gajinder Singh Safri' with revid: 1212323536
# Getting LiftWing ORES scores for 'Ghulam Ghaus' with revid: 1158659195
# Getting LiftWing ORES scores for 'Ghulam Muhammad Ghobar' with revid: 1240993642
# Getting LiftWing ORES scores for 'Hafizullah Shabaz Khail' with revid: 1238402857
# Getting LiftWing ORES scores for 'Haroon al-Afghani' with revid: 1230459615
# Getting LiftWing ORES scores for 'Hashmat Ghani Ahmadzai' with revid: 1207743719
# Getting LiftWing ORES scores for 'Ismael Balkhi' with revid: 1244521219
# Getting LiftWing ORES scores for 'Jan Baz' with revid: 1227635806
# Getting LiftWing ORES scores for 'Khadija Zahra Ahmadi' with revid: 1234741562
# Getting LiftWing ORES scores for 'Mahboba Hoqomal' with revid: 1243745950
# Getting LiftWing ORES scores for 'Majah Ha Adrif' with revid: 1233202991
# Getting LiftWing ORES scores for 'Masoud Khalili' with revid: 1246566971
# Getting LiftWing ORES scores for 'Mirza Muhammad Ismail' with revid: 1235165845
# Getting LiftWing ORES scores for 'Moeen Marastial' with revid: 1246567093
# Getting LiftWing ORES scores for 'Mohammad Daud Miraki' with revid: 1227103354
# Getting LiftWing ORES scores for 'Mohammad Ghous Bashiri' with revid: 1237694188
# Getting LiftWing ORES scores for 'Mohammad Gul (Helmand Council)' with revid: 1136611354
# Getting LiftWing ORES scores for 'Gul Ahmmad Yama' with revid: 1136614561
# Getting LiftWing ORES scores for 'Hanifa Safi' with revid: 1123824802
# Getting LiftWing ORES scores for 'Hasan Ali Sultani' with revid: 1136614726
# Getting LiftWing ORES scores for 'Hysni Curri' with revid: 1198914812
# Getting LiftWing ORES scores for 'Ibrahim Dalliu' with revid: 1248264998
# Getting LiftWing ORES scores for 'Kastriot Berissa' with revid: 1244463139
# Getting LiftWing ORES scores for 'Kostandin Boshnjaku' with revid: 1250227994
# Getting LiftWing ORES scores for 'Mohammad Hashem Taufiqui' with revid: 1233490009
# Getting LiftWing ORES scores for 'Mohammed Qalamuddin' with revid: 1178097642
# Getting LiftWing ORES scores for 'Mohammed Tahir Omar' with revid: 1185088733
# Getting LiftWing ORES scores for 'Mohammed Zaman' with revid: 1229734414
# Getting LiftWing ORES scores for 'Mohammed Zia Salehi' with revid: 1225457074
# Getting LiftWing ORES scores for 'Nasruddin Mohseni' with revid: 1136630129
# Getting LiftWing ORES scores for 'Neritan Ceka' with revid: 1184807608
# Getting LiftWing ORES scores for 'Niazi Demi' with revid: 1209346411
# Getting LiftWing ORES scores for 'Pacha Gul Wafadar' with revid: 1227179979
# Getting LiftWing ORES scores for 'Qari Ziauddin' with revid: 1245217124
# Getting LiftWing ORES scores for 'Refo Çapari' with revid: 1222381064
# Getting LiftWing ORES scores for 'Saber Sangar' with revid: 1227951669
# Getting LiftWing ORES scores for 'Safet Butka' with revid: 1189442848
# Getting LiftWing ORES scores for 'Sardar Mohammad Nadir Naeem' with revid: 1204109653
# Getting LiftWing ORES scores for 'Sayed Nasim Mihanparast' with revid: 1172646418
# Getting LiftWing ORES scores for 'Spartak Braho' with revid: 1224650124
# Getting LiftWing ORES scores for 'Suhail Shaheen' with revid: 1198363158
# Getting LiftWing ORES scores for 'Uran Butka' with revid: 1196422551
# Getting LiftWing ORES scores for 'Wahidullah Waissi' with revid: 1232389768
# Getting LiftWing ORES scores for 'Ylli Asllani' with revid: 1221605713
# Getting LiftWing ORES scores for 'Zabih-U-llah Ghazi Noristani' with revid: 1136614682
# Getting LiftWing ORES scores for 'Zalmai Mujadidi' with revid: 1223903677
# Getting LiftWing ORES scores for 'Ziauddin (Afghan militia leader)' with revid: 1150044800
# Getting LiftWing ORES scores for 'Abas Ermenji' with revid: 1240801210
# Getting LiftWing ORES scores for 'Abdurrahman Dibra' with revid: 1244008227
# Getting LiftWing ORES scores for 'Adrian Neritani' with revid: 1196135017
# Getting LiftWing ORES scores for 'Afrim Tole' with revid: 1241836925
# Getting LiftWing ORES scores for 'Ahmed Dino' with revid: 1209165678
# Getting LiftWing ORES scores for 'Alfred Karamuço' with revid: 1098236555
# Getting LiftWing ORES scores for 'Ali Këlcyra' with revid: 1227369252
# Getting LiftWing ORES scores for 'Aqif Pasha Elbasani' with revid: 1243882903
# Getting LiftWing ORES scores for 'Artur Kuko' with revid: 1112281132
# Getting LiftWing ORES scores for 'Athanas Shundi' with revid: 1220369492
# Getting LiftWing ORES scores for 'Avni Rustemi' with revid: 1229276965
# Getting LiftWing ORES scores for 'Aćif Hadžiahmetović' with revid: 1229938943
# Getting LiftWing ORES scores for 'Bajram Kelmendi' with revid: 1237006808
# Getting LiftWing ORES scores for 'Bedri Pejani' with revid: 1220757655
# Getting LiftWing ORES scores for 'Behxhet Nepravishta' with revid: 1180949734
# Getting LiftWing ORES scores for 'Bujar Dida' with revid: 1222151681
# Getting LiftWing ORES scores for 'Chatin Sarachi' with revid: 1141930406
# Getting LiftWing ORES scores for 'Eduard Shalsi' with revid: 1173107489
# Getting LiftWing ORES scores for 'Elez Koçi' with revid: 1174010569
# Getting LiftWing ORES scores for 'Ferhat Bey Draga' with revid: 1236738861
# Getting LiftWing ORES scores for 'Gjon Markagjoni' with revid: 1227760361
# Getting LiftWing ORES scores for 'High Council of Regency' with revid: 1245450388
# Getting LiftWing ORES scores for 'Hysni Milloshi' with revid: 1218412314
# Getting LiftWing ORES scores for 'Ibrahim Karbunara' with revid: 1235824719
# Getting LiftWing ORES scores for 'Ibrahim Temo' with revid: 1228151428
# Getting LiftWing ORES scores for 'Kadri Prishtina' with revid: 1198167947
# Getting LiftWing ORES scores for 'Kristo Kirka' with revid: 1237950375
# Getting LiftWing ORES scores for 'Kryeziu family' with revid: 1236739222
# Getting LiftWing ORES scores for 'Kurt Agë Kadiu' with revid: 1244486529
# Getting LiftWing ORES scores for 'Mehmed Kalakula' with revid: 1145510350
# Getting LiftWing ORES scores for 'Mehmet Tahsini' with revid: 1239924043
# Getting LiftWing ORES scores for 'Mihal Grameno' with revid: 1226635783
# Getting LiftWing ORES scores for 'Musa Qazimi' with revid: 1235824584
# Getting LiftWing ORES scores for 'Mustafa Ndroqi' with revid: 1198219291
# Getting LiftWing ORES scores for 'Nebi Sefa' with revid: 1244486537
# Getting LiftWing ORES scores for 'Nexhip Draga' with revid: 1236738502
# Getting LiftWing ORES scores for 'Qamil Musa Haxhi Feza' with revid: 1198224146
# Getting LiftWing ORES scores for 'Rasih Dino' with revid: 1180949327
# Getting LiftWing ORES scores for 'Sabit Lulo' with revid: 1180950488
# Getting LiftWing ORES scores for 'Sabri Godo' with revid: 1230739582
# Getting LiftWing ORES scores for 'Sali Nivica' with revid: 1240539074
# Getting LiftWing ORES scores for 'Syreja Vlora' with revid: 1186986269
# Getting LiftWing ORES scores for 'Tefik Mborja' with revid: 1234673487
# Getting LiftWing ORES scores for 'Themistokli Gërmenji' with revid: 1241037317
# Getting LiftWing ORES scores for 'Thoma Orologa' with revid: 1180949774
# Getting LiftWing ORES scores for 'Xhavid Leskoviku' with revid: 1180950536
# Getting LiftWing ORES scores for 'Xhelal Koprëncka' with revid: 1209148780
# Getting LiftWing ORES scores for 'Xhelal Sveçla' with revid: 1217259369
# Getting LiftWing ORES scores for 'Ylli Vesel Shehu' with revid: 1240443327
# Getting LiftWing ORES scores for 'Ymer Prizreni' with revid: 1215667416
# Getting LiftWing ORES scores for 'Abdelhakim Belabed' with revid: 1218173615
# Getting LiftWing ORES scores for 'Abdelkader Zoukh' with revid: 1250270534
# Getting LiftWing ORES scores for 'Abdelkrim Benmbarek' with revid: 1245801726
# Getting LiftWing ORES scores for 'Abderrahmane Meziane Chérif' with revid: 1220757834
# Getting LiftWing ORES scores for 'Abdeslam Bouchouareb' with revid: 1203569345
# Getting LiftWing ORES scores for 'Abdyl Ypi' with revid: 1220281072
# Getting LiftWing ORES scores for 'Aboubakr Belkaid' with revid: 1176411375
# Getting LiftWing ORES scores for 'Ahmed Bidani' with revid: 1212186965
# Getting LiftWing ORES scores for 'Ahmed Hamiani' with revid: 1226452639
# Getting LiftWing ORES scores for 'Ali Aoun' with revid: 1214835889
# Getting LiftWing ORES scores for 'Aïssa Bekkai' with revid: 1219685755
# Getting LiftWing ORES scores for 'Basma Azouar' with revid: 1192088820
# Getting LiftWing ORES scores for 'Benaouda Hadj Hacène Bachterzi' with revid: 1237478919
# Getting LiftWing ORES scores for 'Bouras Djamel' with revid: 1226437538
# Getting LiftWing ORES scores for 'Brahim Chibout' with revid: 1053460621
# Getting LiftWing ORES scores for 'Brahim Djamel Kassali' with revid: 1172500304
# Getting LiftWing ORES scores for 'Chaâbane Aït Abderrahim' with revid: 1234096174
# Getting LiftWing ORES scores for 'Fatiha Serour' with revid: 1218302579
# Getting LiftWing ORES scores for 'Fayçal Bentaleb' with revid: 1217131488
# Getting LiftWing ORES scores for 'Fazia Dahleb' with revid: 1244337610
# Getting LiftWing ORES scores for 'Foued Chehat' with revid: 1242037866
# Getting LiftWing ORES scores for 'Hamza Al Sid Cheikh' with revid: 1248318178
# Getting LiftWing ORES scores for 'Hocine Cherhabil' with revid: 1242619010
# Getting LiftWing ORES scores for 'Ibrahim Boughali' with revid: 1230623499
# Getting LiftWing ORES scores for 'Kamel Beldjoud' with revid: 1214832676
# Getting LiftWing ORES scores for 'Kamel Bidari' with revid: 1249963763
# Getting LiftWing ORES scores for 'Lamine Bechichi' with revid: 1111537825
# Getting LiftWing ORES scores for 'Menduh Zavalani' with revid: 1235824554
# Getting LiftWing ORES scores for 'Mohamed Belouizdad' with revid: 1169278443
# Getting LiftWing ORES scores for 'Mohamed Bensalam' with revid: 1235672021
# Getting LiftWing ORES scores for 'Mohamed Bouslimani' with revid: 1224118485
# Getting LiftWing ORES scores for 'Mohamed Cherif Belmihoub' with revid: 1226553342
# Getting LiftWing ORES scores for 'Mohamed Seghir Babes' with revid: 1226280389
# Getting LiftWing ORES scores for 'Mohamed Tarek Belaribi' with revid: 1241671793
# Getting LiftWing ORES scores for 'Mokhtar Didouche' with revid: 1227200392
# Getting LiftWing ORES scores for 'Nadir Kassab' with revid: 1226271746
# Getting LiftWing ORES scores for 'Nassim Diafat' with revid: 1213342432
# Getting LiftWing ORES scores for 'Noureddine Bahbouh' with revid: 1099284595
# Getting LiftWing ORES scores for 'Rabah Bouaziz' with revid: 1232492563
# Getting LiftWing ORES scores for 'Rachid Bladehane' with revid: 1186319378
# Getting LiftWing ORES scores for 'Saïd Boualam' with revid: 1240883461
# Getting LiftWing ORES scores for 'Saïd Chibane' with revid: 1230435685
# Getting LiftWing ORES scores for 'Exequiel Bustillo' with revid: 1188044851
# Getting LiftWing ORES scores for 'Fabian Jones' with revid: 1247632282
# Getting LiftWing ORES scores for 'Federico Helguera' with revid: 1162056054
# Getting LiftWing ORES scores for 'Germán Alfaro' with revid: 1223272051
# Getting LiftWing ORES scores for 'Guillermo Francos' with revid: 1245178482
# Getting LiftWing ORES scores for 'Harold Lovell' with revid: 1241564680
# Getting LiftWing ORES scores for 'Héctor Bidonde' with revid: 1221160348
# Getting LiftWing ORES scores for 'Héctor Toty Flores' with revid: 1067754685
# Getting LiftWing ORES scores for 'Jamale Pringle' with revid: 1241592215
# Getting LiftWing ORES scores for 'Joanne Massiah' with revid: 1241592526
# Getting LiftWing ORES scores for 'Joaquín Belgrano' with revid: 1229623675
# Getting LiftWing ORES scores for 'Joaquín Samuel de Anchorena' with revid: 1227458965
# Getting LiftWing ORES scores for 'Johnathan Joseph (politician)' with revid: 1241563151
# Getting LiftWing ORES scores for 'Jorge Coscia' with revid: 1227459720
# Getting LiftWing ORES scores for 'Juan Agustín Augier' with revid: 1217815148
# Getting LiftWing ORES scores for 'Juan Alemann' with revid: 1227499891
# Getting LiftWing ORES scores for 'Juan Carlos Del Bello' with revid: 1225784914
# Getting LiftWing ORES scores for 'Juan Fugl' with revid: 1148828249
# Getting LiftWing ORES scores for 'Juan José Gómez Centurión' with revid: 1225793565
# Getting LiftWing ORES scores for 'Kelvin Simon' with revid: 1241592202
# Getting LiftWing ORES scores for 'Kiz Johnson' with revid: 1247632301
# Getting LiftWing ORES scores for 'Knacyntar Nedd' with revid: 1247514093
# Getting LiftWing ORES scores for 'Luis Carlos Gómez Centurión' with revid: 1225793589
# Getting LiftWing ORES scores for 'Luis L. Domínguez' with revid: 1234469779
# Getting LiftWing ORES scores for 'Lázaro Chiappe' with revid: 1232135530
# Getting LiftWing ORES scores for 'Manuel José García' with revid: 1227616001
# Getting LiftWing ORES scores for 'Marco Aurelio Avellaneda' with revid: 1233010330
# Getting LiftWing ORES scores for 'Mario Cafiero' with revid: 1135193654
# Getting LiftWing ORES scores for 'Martín Guzmán' with revid: 1227515965
# Getting LiftWing ORES scores for 'Melford Nicholas' with revid: 1241592535
# Getting LiftWing ORES scores for 'Máximo Etchecopar' with revid: 1243279888
# Getting LiftWing ORES scores for 'Philip Shoul' with revid: 1247632342
# Getting LiftWing ORES scores for 'Rawdon Turner' with revid: 1247632346
# Getting LiftWing ORES scores for 'Rossana Chahla' with revid: 1227517224
# Getting LiftWing ORES scores for 'Santiago Gallo' with revid: 1039135531
# Getting LiftWing ORES scores for 'Shawn Nicholas' with revid: 1247632364
# Getting LiftWing ORES scores for 'Silvano Bores' with revid: 1225775647
# Getting LiftWing ORES scores for 'Uladislao Augier' with revid: 1217815124
# Getting LiftWing ORES scores for 'Abel Posse' with revid: 1245068036
# Getting LiftWing ORES scores for 'Aldo Pignanelli' with revid: 1106856167
# Getting LiftWing ORES scores for 'Alejo Peyret' with revid: 1138003698
# Getting LiftWing ORES scores for 'Alfredo Olmedo' with revid: 1226445117
# Getting LiftWing ORES scores for 'Amán Rawson' with revid: 1226040049
# Getting LiftWing ORES scores for 'Andrias Ghukasyan' with revid: 1214660728
# Getting LiftWing ORES scores for 'Andrés Larroque' with revid: 1248572448
# Getting LiftWing ORES scores for 'Aram Grigoryan (politician)' with revid: 1214660921
# Getting LiftWing ORES scores for 'Aram Manukyan' with revid: 1214661551
# Getting LiftWing ORES scores for 'Arístides Villanueva' with revid: 1227361697
# Getting LiftWing ORES scores for 'Ashot Arsenyan' with revid: 1218601969
# Getting LiftWing ORES scores for 'Carlos Kunkel' with revid: 1225799546
# Getting LiftWing ORES scores for 'Carlos Petroni' with revid: 1199679676
# Getting LiftWing ORES scores for 'Claudio Uberti' with revid: 1245464700
# Getting LiftWing ORES scores for 'Enrique S. Quintana' with revid: 1016343362
# Getting LiftWing ORES scores for 'Fernando Iglesias (Argentine politician)' with revid: 1217866134
# Getting LiftWing ORES scores for 'Fernando Nadra' with revid: 1238199017
# Getting LiftWing ORES scores for 'Gevorg Ghazaryan (politician)' with revid: 1180063729
# Getting LiftWing ORES scores for 'Gevorg Melik-Karagyozyan' with revid: 1180063778
# Getting LiftWing ORES scores for 'Guillermo Montenegro' with revid: 1096175549
# Getting LiftWing ORES scores for 'Gurgen Egiazaryan' with revid: 1103745376
# Getting LiftWing ORES scores for 'Hayk Chobanyan' with revid: 1231768992
# Getting LiftWing ORES scores for 'Hrant Maloyan' with revid: 1250311867
# Getting LiftWing ORES scores for 'Héctor Tizón' with revid: 1222501416
# Getting LiftWing ORES scores for 'Jorge Yoma' with revid: 1191859791
# Getting LiftWing ORES scores for 'Juan Mignaburu' with revid: 1166892817
# Getting LiftWing ORES scores for 'Juan Pablo Schiavi' with revid: 1195011460
# Getting LiftWing ORES scores for 'Julián de Leyva' with revid: 1234698824
# Getting LiftWing ORES scores for 'Khachatur Malumian' with revid: 1210493386
# Getting LiftWing ORES scores for 'Lucio Victorio Mansilla' with revid: 1210433646
# Getting LiftWing ORES scores for 'Marcelo Muniagurria' with revid: 1242262794
# Getting LiftWing ORES scores for 'Mariano Moreno' with revid: 1248788227
# Getting LiftWing ORES scores for 'Martín Menem' with revid: 1247590161
# Getting LiftWing ORES scores for 'Martín Sabbatella' with revid: 1166890663
# Getting LiftWing ORES scores for 'Miguel Ángel Pesce' with revid: 1211044406
# Getting LiftWing ORES scores for 'Mikayel Kotanyan' with revid: 1226313476
# Getting LiftWing ORES scores for 'Mónica López (politician)' with revid: 797826672
# Getting LiftWing ORES scores for 'Nicolás Massot' with revid: 1222899462
# Getting LiftWing ORES scores for 'Norberto La Porta' with revid: 1225799869
# Getting LiftWing ORES scores for 'Parunak Ferukhan' with revid: 1214660598
# Getting LiftWing ORES scores for 'Ricardo Kennedy' with revid: 1240898573
# Getting LiftWing ORES scores for 'Ruben Miroyan' with revid: 1228290809
# Getting LiftWing ORES scores for 'Ruben Mirzakhanyan' with revid: 1214661775
# Getting LiftWing ORES scores for 'Rómulo Sebastián Naón' with revid: 1193099129
# Getting LiftWing ORES scores for 'Santiago G. O'Farrell' with revid: 1228141029
# Getting LiftWing ORES scores for 'Maximilian Anton Karl, Count Baillet de Latour' with revid: 1226152632
# Getting LiftWing ORES scores for 'Michael Killisch-Horn' with revid: 1106829544
# Getting LiftWing ORES scores for 'Narine Tukhikyan' with revid: 1233470777
# Getting LiftWing ORES scores for 'Ohannes Tchekidjian' with revid: 1215201883
# Getting LiftWing ORES scores for 'Paul Paul' with revid: 1215924661
# Getting LiftWing ORES scores for 'Prince Carl of Solms-Braunfels' with revid: 1237091760
# Getting LiftWing ORES scores for 'Richard von Coudenhove-Kalergi' with revid: 1243336388
# Getting LiftWing ORES scores for 'Serop Zakaryan' with revid: 1222543352
# Getting LiftWing ORES scores for 'Sophia Kircher' with revid: 1242552103
# Getting LiftWing ORES scores for 'Suren Shadunts' with revid: 1242146414
# Getting LiftWing ORES scores for 'Theodor Kery' with revid: 1215046740
# Getting LiftWing ORES scores for 'Ulrich Habsburg-Lothringen' with revid: 1216088776
# Getting LiftWing ORES scores for 'Usub Bek Temuryan' with revid: 1243494457
# Getting LiftWing ORES scores for 'Vartkes Serengülian' with revid: 1214669611
# Getting LiftWing ORES scores for 'Walter Guggenberger' with revid: 1154443829
# Getting LiftWing ORES scores for 'Alexander Zach' with revid: 1215187552
# Getting LiftWing ORES scores for 'Aliabbas Salahzade' with revid: 1211047878
# Getting LiftWing ORES scores for 'Anton von Winzor' with revid: 1231556425
# Getting LiftWing ORES scores for 'Brigitta Pallauf' with revid: 1215184008
# Getting LiftWing ORES scores for 'Christoph Matznetter' with revid: 1215054758
# Getting LiftWing ORES scores for 'Curt Franz Wenzel Christoph Erdmann Graf Zedtwitz von Moraván und Duppau' with revid: 1243965585
# Getting LiftWing ORES scores for 'Dilara Aliyeva' with revid: 1236388140
# Getting LiftWing ORES scores for 'Elchin Afandiyev' with revid: 1243626881
# Getting LiftWing ORES scores for 'Elmar Lichtenegger' with revid: 1215483185
# Getting LiftWing ORES scores for 'Emil Sax' with revid: 1215185845
# Getting LiftWing ORES scores for 'Enver Alikhanov' with revid: 1161577254
# Getting LiftWing ORES scores for 'Fazail Agamali' with revid: 1240828387
# Getting LiftWing ORES scores for 'Ferdinand Mannlicher' with revid: 1250188481
# Getting LiftWing ORES scores for 'Franz Leitner (politician)' with revid: 1215054152
# Getting LiftWing ORES scores for 'Franz Moroder' with revid: 1228417930
# Getting LiftWing ORES scores for 'Georg Adam, Prince of Starhemberg' with revid: 1215186237
# Getting LiftWing ORES scores for 'Gerhard Pfanzelter' with revid: 1238011369
# Getting LiftWing ORES scores for 'Gisela Wurm' with revid: 1215187415
# Getting LiftWing ORES scores for 'Gottfried von Kühnelt-Leddihn' with revid: 1235730032
# Getting LiftWing ORES scores for 'Gregor Razumovsky (activist)' with revid: 1236098636
# Getting LiftWing ORES scores for 'Gundaker Thomas Starhemberg' with revid: 1246777408
# Getting LiftWing ORES scores for 'Heidemaria Onodi' with revid: 1246630894
# Getting LiftWing ORES scores for 'Heinz Nittel' with revid: 1226214871
# Getting LiftWing ORES scores for 'Horst Rosenkranz' with revid: 1215185628
# Getting LiftWing ORES scores for 'Hubert Klausner' with revid: 1242810704
# Getting LiftWing ORES scores for 'Johann Anton von Pergen' with revid: 1248404055
# Getting LiftWing ORES scores for 'Johann Gregor Memhardt' with revid: 1226209962
# Getting LiftWing ORES scores for 'Josef Staribacher' with revid: 1215186443
# Getting LiftWing ORES scores for 'Julius Lippert (historian)' with revid: 1248432097
# Getting LiftWing ORES scores for 'Julius Tandler' with revid: 1153989705
# Getting LiftWing ORES scores for 'Józef Kożdoń' with revid: 1215053905
# Getting LiftWing ORES scores for 'Jürgen Mandl' with revid: 1215054486
# Getting LiftWing ORES scores for 'Karl Freiherr von Vogelsang' with revid: 1231556362
# Getting LiftWing ORES scores for 'Karl Lütgendorf' with revid: 1231556108
# Getting LiftWing ORES scores for 'Karl Schmitzer' with revid: 1215186109
# Getting LiftWing ORES scores for 'Karl von Zinzendorf' with revid: 1240906258
# Getting LiftWing ORES scores for 'Leopold, Count von Thun und Hohenstein' with revid: 1215186791
# Getting LiftWing ORES scores for 'Leopold Poetsch' with revid: 1248552155
# Getting LiftWing ORES scores for 'Leyla Abdullayeva' with revid: 1230366514
# Getting LiftWing ORES scores for 'Martin Kocher' with revid: 1241392879
# Getting LiftWing ORES scores for 'Muzamil Abdullayev' with revid: 1223484511
# Getting LiftWing ORES scores for 'Peter Schieder' with revid: 1239601735
# Getting LiftWing ORES scores for 'Peter Strasser (politician)' with revid: 1240951343
# Getting LiftWing ORES scores for 'Reinhold Lopatka' with revid: 1240127163
# Getting LiftWing ORES scores for 'Renate Mann' with revid: 1099978355
# Getting LiftWing ORES scores for 'Sonja Zwazl' with revid: 1235856770
# Getting LiftWing ORES scores for 'Tarlan Aliyarbayov' with revid: 1240965677
# Getting LiftWing ORES scores for 'Thomas Prinzhorn' with revid: 1215185462
# Getting LiftWing ORES scores for 'Walter Pfrimer' with revid: 1249288737
# Getting LiftWing ORES scores for 'Wladimir von Pawlowski' with revid: 1242446030
# Getting LiftWing ORES scores for 'Abdurrahman Fatalibeyli' with revid: 1241052691
# Getting LiftWing ORES scores for 'Afshan Gadimbeyova' with revid: 1243747432
# Getting LiftWing ORES scores for 'Ahmad Kordary' with revid: 1187254621
# Getting LiftWing ORES scores for 'Ajdar Ismailov' with revid: 1157124148
# Getting LiftWing ORES scores for 'Akram Aylisli' with revid: 1247420701
# Getting LiftWing ORES scores for 'Ali Asadov' with revid: 1237483914
# Getting LiftWing ORES scores for 'Ali Huseynli' with revid: 1245270394
# Getting LiftWing ORES scores for 'Ali Ibrahimov' with revid: 1244157806
# Getting LiftWing ORES scores for 'Ali M. Hasanov' with revid: 1245282668
# Getting LiftWing ORES scores for 'Alisahib Huseynov' with revid: 1246588423
# Getting LiftWing ORES scores for 'Alovsat Bakhshiyev' with revid: 1207738330
# Getting LiftWing ORES scores for 'Anar Karimov' with revid: 1245270299
# Getting LiftWing ORES scores for 'Arastun Javadov' with revid: 1147579900
# Getting LiftWing ORES scores for 'Araz Alizadeh' with revid: 1246060446
# Getting LiftWing ORES scores for 'Asaf Hajiyev' with revid: 1235219197
# Getting LiftWing ORES scores for 'Ashraf Bey Taghiyev' with revid: 1213943020
# Getting LiftWing ORES scores for 'Bakhish bey Rustambeyov' with revid: 1246060690
# Getting LiftWing ORES scores for 'Boris Kevorkov' with revid: 1217681945
# Getting LiftWing ORES scores for 'Chimnaz Aslanova' with revid: 1245503366
# Getting LiftWing ORES scores for 'Farhad Hajiyev' with revid: 1246286594
# Getting LiftWing ORES scores for 'Fazail Ibrahimli' with revid: 1243509483
# Getting LiftWing ORES scores for 'Garib Karimoğlu' with revid: 1246060699
# Getting LiftWing ORES scores for 'Gudrat Gasanguliev' with revid: 1234004989
# Getting LiftWing ORES scores for 'Gurban Khalilov' with revid: 1243520102
# Getting LiftWing ORES scores for 'Haji Molla Ahmad Nuruzade' with revid: 1239189558
# Getting LiftWing ORES scores for 'Hasan Hasanli' with revid: 1244589428
# Getting LiftWing ORES scores for 'Hasan Majidov' with revid: 1236490430
# Getting LiftWing ORES scores for 'Huseyngulu Baghirov' with revid: 1199215674
# Getting LiftWing ORES scores for 'Ilham Madatov' with revid: 1011331249
# Getting LiftWing ORES scores for 'Irshad Aliyev' with revid: 1225308278
# Getting LiftWing ORES scores for 'Jamil Hasanli' with revid: 1248447237
# Getting LiftWing ORES scores for 'Jeyhun Jalilov' with revid: 1228687346
# Getting LiftWing ORES scores for 'Lutfali bey Behbudov' with revid: 1226230854
# Getting LiftWing ORES scores for 'Majnun Mammadov' with revid: 1248225337
# Getting LiftWing ORES scores for 'Makhmud Mamed-Guliev' with revid: 1243510539
# Getting LiftWing ORES scores for 'Mamed Iskenderov' with revid: 1244201378
# Getting LiftWing ORES scores for 'Mammad Gurbanov' with revid: 1237445893
# Getting LiftWing ORES scores for 'Mirgasim Cheshmazer' with revid: 1226415908
# Getting LiftWing ORES scores for 'Musa Hacigasimov' with revid: 1236490449
# Getting LiftWing ORES scores for 'Musa Mammadov' with revid: 1243510550
# Getting LiftWing ORES scores for 'Ramin Mammadov' with revid: 1248662299
# Getting LiftWing ORES scores for 'Rovshan Javadov' with revid: 1250266366
# Getting LiftWing ORES scores for 'Saftar Jafarov' with revid: 1222623261
# Getting LiftWing ORES scores for 'Sahil Babayev' with revid: 1207600921
# Getting LiftWing ORES scores for 'Solomon Grobshtein' with revid: 1067081975
# Getting LiftWing ORES scores for 'Teymur Guliyev' with revid: 1232296078
# Getting LiftWing ORES scores for 'Vidadi Isgandarov' with revid: 1249203876
# Getting LiftWing ORES scores for 'Vilayat Eyvazov' with revid: 1208072134
# Getting LiftWing ORES scores for 'Zakir Hasanov' with revid: 1224596001
# Getting LiftWing ORES scores for 'Abdulla Adel Fakhro' with revid: 1223700072
# Getting LiftWing ORES scores for 'Abdullah bin Isa Al Khalifa' with revid: 1182830303
# Getting LiftWing ORES scores for 'Abid Sharifov' with revid: 1243510547
# Getting LiftWing ORES scores for 'Ahmed Behzad (Bahrain)' with revid: 1063482737
# Getting LiftWing ORES scores for 'Ammar Al Bannai' with revid: 1231654401
# Getting LiftWing ORES scores for 'Aymen Tawfeeq Almoayed' with revid: 1227286508
# Getting LiftWing ORES scores for 'Bakhtiyar Vahabzadeh' with revid: 1249675761
# Getting LiftWing ORES scores for 'Charles Carter (Bahamian journalist)' with revid: 1162793449
# Getting LiftWing ORES scores for 'Eldar Namazov' with revid: 1206211739
# Getting LiftWing ORES scores for 'Elshad Mirbashir oghlu' with revid: 1194162044
# Getting LiftWing ORES scores for 'Eugene Dupuch' with revid: 1181612386
# Getting LiftWing ORES scores for 'Faisal al-Hamar' with revid: 1218302538
# Getting LiftWing ORES scores for 'Fuad Naghiyev' with revid: 1248662296
# Getting LiftWing ORES scores for 'Harold Christie' with revid: 1142294843
# Getting LiftWing ORES scores for 'Hasan Seyidov' with revid: 1148385245
# Getting LiftWing ORES scores for 'Hasan Seyidov (scientist)' with revid: 1198202282
# Getting LiftWing ORES scores for 'Huseyn Rahmanov' with revid: 1106104383
# Getting LiftWing ORES scores for 'Ikhtiyar Shirinov' with revid: 1243510572
# Getting LiftWing ORES scores for 'Isa bin Abdulrahman Al Hammadi' with revid: 1098344827
# Getting LiftWing ORES scores for 'Isa bin Ibrahim Al Khalifa' with revid: 1146485875
# Getting LiftWing ORES scores for 'Jameel Humadan' with revid: 1148959062
# Getting LiftWing ORES scores for 'James Carmichael Smith (postmaster)' with revid: 1248344476
# Getting LiftWing ORES scores for 'Jawad Fairooz' with revid: 1177286981
# Getting LiftWing ORES scores for 'Joseph Robert Love' with revid: 1177467150
# Getting LiftWing ORES scores for 'Kamal Ahmed (politician)' with revid: 1215486840
# Getting LiftWing ORES scores for 'Keith Bell (Bahamian politician)' with revid: 1243023554
# Getting LiftWing ORES scores for 'Khalid Almoayed' with revid: 1215466172
# Getting LiftWing ORES scores for 'Mahmood Al Bahrani' with revid: 1161492589
# Getting LiftWing ORES scores for 'Mammad agha Shahtakhtinski' with revid: 1185599926
# Getting LiftWing ORES scores for 'McKell Bonaby' with revid: 1238577650
# Getting LiftWing ORES scores for 'Mohamed Ali Hasan Ali' with revid: 1006173162
# Getting LiftWing ORES scores for 'Mohammed Isa Al Abbasi' with revid: 1171757402
# Getting LiftWing ORES scores for 'Movsum Samadov' with revid: 1241255046
# Getting LiftWing ORES scores for 'Nabeel bin Yaqub Al-Hamar' with revid: 1159628135
# Getting LiftWing ORES scores for 'Namig Nasrullayev' with revid: 1158375491
# Getting LiftWing ORES scores for 'Nazar Al Baharna' with revid: 1241906132
# Getting LiftWing ORES scores for 'Nurali Yusifbayli' with revid: 1243510541
# Getting LiftWing ORES scores for 'Pakesia Parker-Edgecombe' with revid: 1226025677
# Getting LiftWing ORES scores for 'Parviz Shahbazov' with revid: 1213858589
# Getting LiftWing ORES scores for 'Qasim Fakhro' with revid: 1099067663
# Getting LiftWing ORES scores for 'Rovshen Rzayev' with revid: 1208078338
# Getting LiftWing ORES scores for 'Sadig Rahimov' with revid: 1245157534
# Getting LiftWing ORES scores for 'Shirali Akhundov' with revid: 1213002608
# Getting LiftWing ORES scores for 'Siyavush Novruzov' with revid: 1243520070
# Getting LiftWing ORES scores for 'Suleyman Rahimov' with revid: 1193027962
# Getting LiftWing ORES scores for 'Tahir Mirkishili' with revid: 1210593900
# Getting LiftWing ORES scores for 'James Chikerema' with revid: 1247967827
# Getting LiftWing ORES scores for 'Joseph Makamba Busha' with revid: 1215996308
# Getting LiftWing ORES scores for 'Lily Monze' with revid: 1245511378
# Getting LiftWing ORES scores for 'Mohamed al-Atifi' with revid: 1243159603
# Getting LiftWing ORES scores for 'Mohammed Ali Al-Maqdashi' with revid: 1228062555
# Getting LiftWing ORES scores for 'Mohammed Lutf al-Iryani' with revid: 1219000221
# Getting LiftWing ORES scores for 'Mohammed al-Sabry' with revid: 1232803611
# Getting LiftWing ORES scores for 'Muhammad Musa al-Amri' with revid: 1144463258
# Getting LiftWing ORES scores for 'Muhammad bin Yahya bin Muhammad' with revid: 1231305316
# Getting LiftWing ORES scores for 'Olipa Phiri' with revid: 1180049589
# Getting LiftWing ORES scores for 'Paul Chimedza' with revid: 1226620788
# Getting LiftWing ORES scores for 'Phan Anh' with revid: 1224595790
# Getting LiftWing ORES scores for 'Sagheer Hamoud Aziz' with revid: 1247681445
# Getting LiftWing ORES scores for 'Sam Yahya Al-Ahmar' with revid: 1247681434
# Getting LiftWing ORES scores for 'Sultan al-Barakani' with revid: 1246507826
# Getting LiftWing ORES scores for 'Talal Aklan' with revid: 1242218278
# Getting LiftWing ORES scores for 'Tran Minh Tiet' with revid: 1225066058
# Getting LiftWing ORES scores for 'Trương Đình Dzu' with revid: 1220804010
# Getting LiftWing ORES scores for 'Trần Quốc Vượng (politician)' with revid: 1237490552
# Getting LiftWing ORES scores for 'Trần Văn Hữu' with revid: 1244544286
# Getting LiftWing ORES scores for 'Tạ Quang Bửu' with revid: 1224595798
# Getting LiftWing ORES scores for 'Võ Văn Thưởng' with revid: 1241845313
# Getting LiftWing ORES scores for 'Yahya Mohamed Abdullah Saleh' with revid: 1223542345
# Getting LiftWing ORES scores for 'Yahya Muhammad Hamid ed-Din' with revid: 1249145023
# Getting LiftWing ORES scores for 'Yasser Al-Awadi' with revid: 1129096674
# Getting LiftWing ORES scores for 'Abel Muzorewa' with revid: 1246262690
# Getting LiftWing ORES scores for 'Aguy Georgias' with revid: 1233377690
# Getting LiftWing ORES scores for 'Alfred Makwarimba' with revid: 1092395186
# Getting LiftWing ORES scores for 'Andre Sothern Holland' with revid: 1203015285
# Getting LiftWing ORES scores for 'Anxious Masuka' with revid: 1247106176
# Getting LiftWing ORES scores for 'Bekithemba Mpofu' with revid: 1085044064
# Getting LiftWing ORES scores for 'Bright Matonga' with revid: 1036801272
# Getting LiftWing ORES scores for 'Byron Hove' with revid: 1226322417
# Getting LiftWing ORES scores for 'Daniel Shumba' with revid: 1154573139
# Getting LiftWing ORES scores for 'Earnest Mudzengi' with revid: 1246271197
# Getting LiftWing ORES scores for 'Edwin Mushoriwa' with revid: 1246239657
# Getting LiftWing ORES scores for 'Ellen Gwaradzimba' with revid: 1246241932
# Getting LiftWing ORES scores for 'Elliot Manyika' with revid: 1246001588
# Getting LiftWing ORES scores for 'Engelbert Rugeje' with revid: 1221940918
# Getting LiftWing ORES scores for 'Fletcher Dulini Ncube' with revid: 1236276553
# Getting LiftWing ORES scores for 'Maxwell Zeb Shumba' with revid: 1246242430
# Getting LiftWing ORES scores for 'Nkululeko Mkastos Sibanda' with revid: 1243016866
# Getting LiftWing ORES scores for 'Rekayi Tangwena' with revid: 1236117496
# Getting LiftWing ORES scores for 'Sengezo Tshabangu' with revid: 1228478288
# Getting LiftWing ORES scores for 'Temba Mliswa' with revid: 1246241769
#
# The following articles failed to get an ORES score:
# - Carlos Pineda (politician)
# - János Ghyczy
# - Klemen Boštjančič

# %% [markdown]
# # Clean ORES Output for Data Analysis
#
# This code contains a function called extract_predictions that creates a dictionary retaining only article title and its corresponding revision ID and prediction.
#
# It also prints the article names of article-revision ID pairs who did not previously trip the error in the ORES function, but which lack the suficient prediction data to be analyzed. These articles will not be included in the analysis due to their incomplete data.

# %%
# Load the JSON data from the file
with open('politicians_final_ORES_scores.json', 'r') as json_file:
    input_dict = json.load(json_file)

# Function to extract the prediction for each entry in the dictionary
def extract_predictions(article_dict):
    result = {}
    
    for name, details in article_dict.items():
        try:
            # Get the revision ID as a string
            rev_id = str(details['rev_id'])
            
            # Index through the nested structure to get the 'prediction'
            prediction = details['ores_score']['enwiki']['scores'][rev_id]['articlequality']['score']['prediction']
            
            # Store the name, rev_id, and prediction in the result dictionary
            result[name] = {
                'rev_id': rev_id,
                'prediction': prediction
            }
        except KeyError as e:
            # If any required key is missing, print an error message and continue
            print(f"KeyError for {name}: {e}")
    
    return result

# Extract predictions for all entries in the dictionary
predictions_dict = extract_predictions(input_dict)

# Print the result
for name, data in predictions_dict.items():
    print(f"{name}: rev_id = {data['rev_id']}, prediction = {data['prediction']}")
# Out:
# KeyError for Josip Ferfolja: 'enwiki'
# KeyError for Nerio Giovanazzi: 'enwiki'
# KeyError for Bernice Dahn: 'enwiki'
# KeyError for Karol Dembovský: 'enwiki'
# Abdul Baqi Turkistani: rev_id = 1231655023, prediction = Stub
# Abdul Ghani Ghani: rev_id = 1227026187, prediction = Stub
# Abdul Rahim Ayoubi: rev_id = 1226326055, prediction = Start
# Ahmad Wali Massoud: rev_id = 1221720658, prediction = Start
# Aimal Faizi: rev_id = 1185105938, prediction = Stub
# Amir Muhammad Akhundzada: rev_id = 1247931713, prediction = Start
# Aziza Ahmadyar: rev_id = 1195651393, prediction = Start
# Azizullah Lodin: rev_id = 1247762293, prediction = Start
# Baran Khan Kudezai: rev_id = 1176481824, prediction = Start
# Bashir Ahmad Bezan: rev_id = 1248505877, prediction = Start
# Cheragh Ali Cheragh: rev_id = 1193992206, prediction = Start
# Ezatullah (Nangarhar): rev_id = 1158302291, prediction = Stub
# Fazel Ahmed Manawi: rev_id = 1234514379, prediction = Start
# Gajinder Singh Safri: rev_id = 1212323536, prediction = Stub
# Ghulam Ghaus: rev_id = 1158659195, prediction = Stub
# Ghulam Muhammad Ghobar: rev_id = 1240993642, prediction = Stub
# Hafizullah Shabaz Khail: rev_id = 1238402857, prediction = Start
# Haroon al-Afghani: rev_id = 1230459615, prediction = B
# Hashmat Ghani Ahmadzai: rev_id = 1207743719, prediction = C
# Ismael Balkhi: rev_id = 1244521219, prediction = Start
# Jan Baz: rev_id = 1227635806, prediction = Stub
# Khadija Zahra Ahmadi: rev_id = 1234741562, prediction = Stub
# Mahboba Hoqomal: rev_id = 1243745950, prediction = Stub
# Majah Ha Adrif: rev_id = 1233202991, prediction = Start
# Masoud Khalili: rev_id = 1246566971, prediction = GA
# Mirza Muhammad Ismail: rev_id = 1235165845, prediction = C
# Moeen Marastial: rev_id = 1246567093, prediction = Start
# Mohammad Daud Miraki: rev_id = 1227103354, prediction = C
# Mohammad Ghous Bashiri: rev_id = 1237694188, prediction = Start
# Mohammad Gul (Helmand Council): rev_id = 1136611354, prediction = Stub
# Mohammad Khan (athlete): rev_id = 1247727443, prediction = Stub
# Mohammad Sarwar Ahmedzai: rev_id = 1176429234, prediction = Start
# Mohammad Siddiq Chakari: rev_id = 1134129082, prediction = Stub
# Muhammad Hashim Esmatullahi: rev_id = 949986748, prediction = Stub
# Muqadasa Ahmadzai: rev_id = 1235521766, prediction = Start
# Musa Hotak: rev_id = 1246566804, prediction = Start
# Nasir Ahmad Durrani: rev_id = 988838315, prediction = Stub
# Nasrullah Baryalai Arsalai: rev_id = 1225385278, prediction = Start
# Qutbuddin Hilal: rev_id = 1246566795, prediction = Start
# Rafiullah Bidar: rev_id = 1197443408, prediction = Stub
# Rangina Hamidi: rev_id = 1234743111, prediction = C
# Razaq Mamoon: rev_id = 1227180106, prediction = Start
# Said Tayeb Jawad: rev_id = 1248976824, prediction = C
# Samoud Khan: rev_id = 1195409073, prediction = Start
# Sayed Jalal: rev_id = 1137130537, prediction = Start
# Sayed Jalal Karim: rev_id = 1136614743, prediction = Start
# Sayed Yousuf Halim: rev_id = 1234514565, prediction = Stub
# Sayed Zafar Hashemi: rev_id = 1179137138, prediction = Start
# Sharif Ghalib: rev_id = 1245967190, prediction = Start
# Tayyab Agha: rev_id = 1225661708, prediction = Start
# Abdul Ghafor Zori: rev_id = 1136614520, prediction = Stub
# Abdul Karim Misaq: rev_id = 1235405154, prediction = Stub
# Abdul Majid Samim: rev_id = 1225425205, prediction = Stub
# Abdul Salam Zaeef: rev_id = 1243758857, prediction = GA
# Abdul Sattar Mirzakwal: rev_id = 1145249317, prediction = Stub
# Abdul Zahir (Konar Education Minister): rev_id = 1126667481, prediction = Stub
# Ahmadullah Wasiq: rev_id = 1171042170, prediction = Start
# Ali Mohammad (politician): rev_id = 1136630194, prediction = Stub
# Ali Pasha of Gusinje: rev_id = 1244421894, prediction = GA
# Azis Tahir Ajdonati: rev_id = 1192928746, prediction = Stub
# Baktash Siawash: rev_id = 1236603169, prediction = Stub
# Bardhok Biba: rev_id = 1250227174, prediction = C
# Bislim Bajgora: rev_id = 1217284690, prediction = C
# Daoud Naji: rev_id = 1247131367, prediction = Start
# Davood Moradian: rev_id = 1239319380, prediction = Stub
# Fazal Hadi Shinwari: rev_id = 1242412237, prediction = GA
# Gholam Rabani Nasher: rev_id = 1136534788, prediction = Stub
# Ghulam Faroq Nijrabi: rev_id = 1136614778, prediction = Stub
# Ghulam Hassan Safi: rev_id = 1176507815, prediction = Stub
# Ghulam Mohammad Rigi: rev_id = 1129192917, prediction = Stub
# Gul Ahmmad Yama: rev_id = 1136614561, prediction = Start
# Hanifa Safi: rev_id = 1123824802, prediction = Stub
# Hasan Ali Sultani: rev_id = 1136614726, prediction = Stub
# Hysni Curri: rev_id = 1198914812, prediction = Start
# Ibrahim Dalliu: rev_id = 1248264998, prediction = Start
# Kastriot Berissa: rev_id = 1244463139, prediction = Start
# Kostandin Boshnjaku: rev_id = 1250227994, prediction = C
# Mohammad Hashem Taufiqui: rev_id = 1233490009, prediction = Start
# Mohammed Qalamuddin: rev_id = 1178097642, prediction = Stub
# Mohammed Tahir Omar: rev_id = 1185088733, prediction = Stub
# Mohammed Zaman: rev_id = 1229734414, prediction = Start
# Mohammed Zia Salehi: rev_id = 1225457074, prediction = Stub
# Nasruddin Mohseni: rev_id = 1136630129, prediction = Start
# Neritan Ceka: rev_id = 1184807608, prediction = Start
# Niazi Demi: rev_id = 1209346411, prediction = Stub
# Pacha Gul Wafadar: rev_id = 1227179979, prediction = Stub
# Qari Ziauddin: rev_id = 1245217124, prediction = Start
# Refo Çapari: rev_id = 1222381064, prediction = Start
# Saber Sangar: rev_id = 1227951669, prediction = Stub
# Safet Butka: rev_id = 1189442848, prediction = C
# Sardar Mohammad Nadir Naeem: rev_id = 1204109653, prediction = Stub
# Sayed Nasim Mihanparast: rev_id = 1172646418, prediction = Stub
# Spartak Braho: rev_id = 1224650124, prediction = Start
# Suhail Shaheen: rev_id = 1198363158, prediction = Start
# Uran Butka: rev_id = 1196422551, prediction = Start
# Wahidullah Waissi: rev_id = 1232389768, prediction = C
# Ylli Asllani: rev_id = 1221605713, prediction = Start
# Zabih-U-llah Ghazi Noristani: rev_id = 1136614682, prediction = Start
# Zalmai Mujadidi: rev_id = 1223903677, prediction = Start
# Ziauddin (Afghan militia leader): rev_id = 1150044800, prediction = Start
# Abas Ermenji: rev_id = 1240801210, prediction = Start
# Abdurrahman Dibra: rev_id = 1244008227, prediction = Start
# Adrian Neritani: rev_id = 1196135017, prediction = Start
# Afrim Tole: rev_id = 1241836925, prediction = Stub
# Ahmed Dino: rev_id = 1209165678, prediction = Stub
# Alfred Karamuço: rev_id = 1098236555, prediction = Stub
# Ali Këlcyra: rev_id = 1227369252, prediction = Start
# Aqif Pasha Elbasani: rev_id = 1243882903, prediction = GA
# Artur Kuko: rev_id = 1112281132, prediction = Stub
# Athanas Shundi: rev_id = 1220369492, prediction = C
# Avni Rustemi: rev_id = 1229276965, prediction = Start
# Aćif Hadžiahmetović: rev_id = 1229938943, prediction = GA
# Bajram Kelmendi: rev_id = 1237006808, prediction = Start
# Bedri Pejani: rev_id = 1220757655, prediction = C
# Behxhet Nepravishta: rev_id = 1180949734, prediction = Stub
# Bujar Dida: rev_id = 1222151681, prediction = C
# Chatin Sarachi: rev_id = 1141930406, prediction = C
# Eduard Shalsi: rev_id = 1173107489, prediction = Start
# Elez Koçi: rev_id = 1174010569, prediction = Start
# Ferhat Bey Draga: rev_id = 1236738861, prediction = C
# Gjon Markagjoni: rev_id = 1227760361, prediction = C
# High Council of Regency: rev_id = 1245450388, prediction = C
# Hysni Milloshi: rev_id = 1218412314, prediction = Start
# Ibrahim Karbunara: rev_id = 1235824719, prediction = C
# Ibrahim Temo: rev_id = 1228151428, prediction = GA
# Kadri Prishtina: rev_id = 1198167947, prediction = Start
# Kristo Kirka: rev_id = 1237950375, prediction = C
# Kryeziu family: rev_id = 1236739222, prediction = Start
# Kurt Agë Kadiu: rev_id = 1244486529, prediction = Stub
# Mehmed Kalakula: rev_id = 1145510350, prediction = Stub
# Mehmet Tahsini: rev_id = 1239924043, prediction = Stub
# Mihal Grameno: rev_id = 1226635783, prediction = C
# Musa Qazimi: rev_id = 1235824584, prediction = GA
# Mustafa Ndroqi: rev_id = 1198219291, prediction = Stub
# Nebi Sefa: rev_id = 1244486537, prediction = Stub
# Nexhip Draga: rev_id = 1236738502, prediction = GA
# Qamil Musa Haxhi Feza: rev_id = 1198224146, prediction = Stub
# Rasih Dino: rev_id = 1180949327, prediction = Stub
# Sabit Lulo: rev_id = 1180950488, prediction = Stub
# Sabri Godo: rev_id = 1230739582, prediction = C
# Sali Nivica: rev_id = 1240539074, prediction = Start
# Syreja Vlora: rev_id = 1186986269, prediction = Start
# Tefik Mborja: rev_id = 1234673487, prediction = Start
# Themistokli Gërmenji: rev_id = 1241037317, prediction = C
# Thoma Orologa: rev_id = 1180949774, prediction = Start
# Xhavid Leskoviku: rev_id = 1180950536, prediction = Start
# Xhelal Koprëncka: rev_id = 1209148780, prediction = Stub
# Xhelal Sveçla: rev_id = 1217259369, prediction = Start
# Ylli Vesel Shehu: rev_id = 1240443327, prediction = Stub
# Ymer Prizreni: rev_id = 1215667416, prediction = Start
# Abdelhakim Belabed: rev_id = 1218173615, prediction = Start
# Abdelkader Zoukh: rev_id = 1250270534, prediction = Start
# Abdelkrim Benmbarek: rev_id = 1245801726, prediction = Stub
# Abderrahmane Meziane Chérif: rev_id = 1220757834, prediction = Start
# Abdeslam Bouchouareb: rev_id = 1203569345, prediction = Stub
# Abdyl Ypi: rev_id = 1220281072, prediction = Stub
# Aboubakr Belkaid: rev_id = 1176411375, prediction = Start
# Ahmed Bidani: rev_id = 1212186965, prediction = Start
# Ahmed Hamiani: rev_id = 1226452639, prediction = Stub
# Ali Aoun: rev_id = 1214835889, prediction = Start
# Aïssa Bekkai: rev_id = 1219685755, prediction = Stub
# Basma Azouar: rev_id = 1192088820, prediction = Stub
# Benaouda Hadj Hacène Bachterzi: rev_id = 1237478919, prediction = Stub
# Bouras Djamel: rev_id = 1226437538, prediction = Stub
# Brahim Chibout: rev_id = 1053460621, prediction = Stub
# Brahim Djamel Kassali: rev_id = 1172500304, prediction = Start
# Chaâbane Aït Abderrahim: rev_id = 1234096174, prediction = Start
# Fatiha Serour: rev_id = 1218302579, prediction = Start
# Fayçal Bentaleb: rev_id = 1217131488, prediction = Stub
# Fazia Dahleb: rev_id = 1244337610, prediction = Stub
# Foued Chehat: rev_id = 1242037866, prediction = Stub
# Hamza Al Sid Cheikh: rev_id = 1248318178, prediction = Stub
# Hocine Cherhabil: rev_id = 1242619010, prediction = Stub
# Ibrahim Boughali: rev_id = 1230623499, prediction = Stub
# Kamel Beldjoud: rev_id = 1214832676, prediction = Stub
# Kamel Bidari: rev_id = 1249963763, prediction = GA
# Lamine Bechichi: rev_id = 1111537825, prediction = Stub
# Menduh Zavalani: rev_id = 1235824554, prediction = FA
# Mohamed Belouizdad: rev_id = 1169278443, prediction = Start
# Mohamed Bensalam: rev_id = 1235672021, prediction = Stub
# Mohamed Bouslimani: rev_id = 1224118485, prediction = Stub
# Mohamed Cherif Belmihoub: rev_id = 1226553342, prediction = Start
# Mohamed Seghir Babes: rev_id = 1226280389, prediction = Stub
# Mohamed Tarek Belaribi: rev_id = 1241671793, prediction = Start
# Mokhtar Didouche: rev_id = 1227200392, prediction = Start
# Nadir Kassab: rev_id = 1226271746, prediction = Stub
# Nassim Diafat: rev_id = 1213342432, prediction = Stub
# Noureddine Bahbouh: rev_id = 1099284595, prediction = Stub
# Rabah Bouaziz: rev_id = 1232492563, prediction = Start
# Rachid Bladehane: rev_id = 1186319378, prediction = Stub
# Saïd Boualam: rev_id = 1240883461, prediction = Start
# Saïd Chibane: rev_id = 1230435685, prediction = Stub
# Souad Bendjaballah: rev_id = 1134649751, prediction = Stub
# Taha Derbal: rev_id = 1213344636, prediction = Stub
# Visar Ymeri: rev_id = 1248230838, prediction = Stub
# Visarion Xhuvani: rev_id = 1135323365, prediction = C
# Xhezair Zaganjori: rev_id = 1143896123, prediction = Start
# Yahia Boukhari: rev_id = 1186319308, prediction = Stub
# Youcef Belmehdi: rev_id = 1239235131, prediction = Stub
# Youcef Chorfa: rev_id = 1214834266, prediction = Start
# Abdelhak Saihi: rev_id = 1218004839, prediction = Stub
# Abderezak Sebgag: rev_id = 1212579707, prediction = Stub
# Abderrachid Tabbi: rev_id = 1218530483, prediction = Stub
# Abel Chivukuvuku: rev_id = 1165626565, prediction = Start
# Abraão Gourgel: rev_id = 1124441544, prediction = Stub
# Adalberto Costa Júnior: rev_id = 1244123151, prediction = Stub
# Adjany Costa: rev_id = 1242000475, prediction = Start
# Adão Francisco Correia de Almeida: rev_id = 1209524394, prediction = Stub
# Ahmed Zeghdar: rev_id = 1213778323, prediction = Stub
# Alexandre Sebastião André: rev_id = 1172178750, prediction = Stub
# Amar Makhloufi: rev_id = 1235394946, prediction = Stub
# Amar Mohammedi: rev_id = 1226279231, prediction = Start
# Ana Paula Chantre Luna de Carvalho: rev_id = 1209514022, prediction = Stub
# Arlete Chimbinda: rev_id = 1177486404, prediction = Start
# Azzedine Mihoubi: rev_id = 1233387309, prediction = Start
# Bachir Messaitfa: rev_id = 1186318318, prediction = Stub
# Bernarda Gonçalves Martins: rev_id = 1210193481, prediction = Stub
# Brahim Merad: rev_id = 1244511083, prediction = Start
# Carolina Cerqueira: rev_id = 1241977204, prediction = C
# Cherif Rahmani: rev_id = 1053461144, prediction = Stub
# Diamantino Pedro Azevedo: rev_id = 1209522689, prediction = Stub
# Faustina Fernandes Inglês de Almeida Alves: rev_id = 1209514085, prediction = Stub
# Fiel Domingos Constantino: rev_id = 1217387083, prediction = Stub
# Hichem Sofiane Salaouatchi: rev_id = 1212186286, prediction = Stub
# Jeremias Chitunda: rev_id = 1220287872, prediction = Start
# Jesus Faria Maiato: rev_id = 1209631313, prediction = Stub
# Jofre Van-Dúnem Júnior: rev_id = 1242307432, prediction = Stub
# José Carvalho da Rocha: rev_id = 1242307441, prediction = Stub
# José Luis de Matos: rev_id = 1242307337, prediction = Stub
# João Baptista Borges: rev_id = 1227794006, prediction = C
# Kafundanga Chingunji: rev_id = 1191431794, prediction = Stub
# Kambamba Kulaxingo: rev_id = 1093124425, prediction = Stub
# Kamel Rezig: rev_id = 1215901775, prediction = Stub
# Kaoutar Krikou: rev_id = 1213795388, prediction = Stub
# Karim Bibi Triki: rev_id = 1213794210, prediction = Start
# Laid Rebiga: rev_id = 1248662394, prediction = Stub
# Lakhdar Rakhroukh: rev_id = 1186317568, prediction = Stub
# Layachi Yaker: rev_id = 1226060720, prediction = Start
# Mohamed Ali Boughazi: rev_id = 1213870570, prediction = Start
# Mohamed Maghlaoui: rev_id = 1053469610, prediction = Stub
# Naima Salhi: rev_id = 1213404244, prediction = Stub
# Paulino Baptista: rev_id = 1242307496, prediction = Start
# Raul Danda: rev_id = 1158035855, prediction = Stub
# Salim Saadi: rev_id = 1229426851, prediction = Stub
# Samia Moualfi: rev_id = 1212181372, prediction = Stub
# Sassi Lamouri: rev_id = 1181986973, prediction = Stub
# Soraya Mouloudji: rev_id = 1226335614, prediction = Stub
# Yacine Oualid: rev_id = 1214837789, prediction = Stub
# Yassine Merabi: rev_id = 1214841607, prediction = Stub
# Álvaro Arnaldo Craveiro: rev_id = 1194150567, prediction = Stub
# Alex Browne (politician): rev_id = 1247631794, prediction = Stub
# Ana Paula Sacramento Neto: rev_id = 1227909121, prediction = Stub
# Augusto da Silva Tomás: rev_id = 1219179734, prediction = Stub
# Branca Manuel Espirito Santo: rev_id = 1142474441, prediction = Stub
# Caleb Gardiner: rev_id = 1241563135, prediction = Stub
# Cheryl Mary Clare Hurst: rev_id = 1242813942, prediction = Stub
# Clement Antonio: rev_id = 1241563106, prediction = Stub
# Colin O'Neil Browne: rev_id = 1241563118, prediction = Stub
# Daniel Ntongi-Nzinga: rev_id = 1187961349, prediction = Stub
# David Mendes: rev_id = 1024544204, prediction = Stub
# Elias Salupeto Pena: rev_id = 1220287990, prediction = Start
# Fernando Faustino Muteka: rev_id = 1241977176, prediction = Stub
# Francisco Manuel Monteiro de Queiróz: rev_id = 1242307454, prediction = Stub
# Gail Christian: rev_id = 1241563122, prediction = Start
# James Carlisle: rev_id = 1242152285, prediction = C
# Johnny Eduardo Pinnock: rev_id = 1242307359, prediction = Stub
# Jonas Savimbi: rev_id = 1246026420, prediction = GA
# José Aníbal Lopes Rocha: rev_id = 1242307479, prediction = Stub
# José Filomeno dos Santos: rev_id = 1228399791, prediction = C
# José Jacinto Van-Dúnem: rev_id = 1242841039, prediction = C
# José Ndele: rev_id = 1154991360, prediction = Stub
# José Vieira Dias Van-Dúnem: rev_id = 1227004140, prediction = Stub
# José da Rocha: rev_id = 1153488959, prediction = Stub
# João Ernesto dos Santos: rev_id = 1226309621, prediction = Stub
# Luzia Inglês Van-Dúnem: rev_id = 1240720719, prediction = Start
# Luís Gomes Sambo: rev_id = 1242306989, prediction = Start
# Mackenzie Frank: rev_id = 1247632329, prediction = Stub
# Manuel Bernardo de Sousa: rev_id = 1233607984, prediction = Stub
# Manuel Neto da Costa: rev_id = 1209411144, prediction = Stub
# Manuel Tavares de Almeida: rev_id = 1209411217, prediction = Stub
# Manuel Vicente: rev_id = 1250493481, prediction = C
# Marcos Alexandre Nhunga: rev_id = 1209413818, prediction = Stub
# Maria Cândida Pereira Teixeira: rev_id = 1218506469, prediction = Stub
# Maria do Rosário Teixeira de Alva Sequeira Bragança Sambo: rev_id = 1209513699, prediction = Stub
# Mfulupinga Nlando Victor: rev_id = 1243272129, prediction = Start
# Osbert Richard Frederick: rev_id = 1241563130, prediction = Start
# Paula Cristina Francisco Coelho: rev_id = 1209410923, prediction = Stub
# Pedro Mutinde: rev_id = 1209539718, prediction = Start
# Pedro Pedalé: rev_id = 1115715527, prediction = Stub
# Pinda Simão: rev_id = 1118804168, prediction = Stub
# Randolph Beazer: rev_id = 1247631912, prediction = Stub
# Rick James (actor): rev_id = 1213836084, prediction = C
# Rosa Luís de Sousa Micolo: rev_id = 1246271741, prediction = Stub
# Santana André Pitra: rev_id = 1165626399, prediction = Stub
# Saíde Mingas: rev_id = 1242306726, prediction = GA
# Shenella Mary Shadida Govia: rev_id = 1241563138, prediction = Stub
# Studiation Brown: rev_id = 825090349, prediction = Stub
# Tim Hector: rev_id = 1227026341, prediction = C
# Wilfred Jacobs: rev_id = 1246340247, prediction = Stub
# William Haynes-Smith: rev_id = 1242257328, prediction = C
# Alberto Manuel Campos: rev_id = 1166331326, prediction = Start
# Alejo Castex: rev_id = 1231276700, prediction = C
# Alincia Williams-Grant: rev_id = 1241592542, prediction = Start
# Antonio Bermejo: rev_id = 1225811362, prediction = Start
# Antonio Beruti: rev_id = 1243926512, prediction = Start
# Bernard Percival: rev_id = 1241564686, prediction = Stub
# Carlos Corach: rev_id = 1227620960, prediction = Stub
# Carlos de la Rosa: rev_id = 1209668330, prediction = Stub
# David Massiah: rev_id = 1247632248, prediction = Stub
# Dwayne George: rev_id = 1247631631, prediction = Stub
# Dámaso Centeno: rev_id = 1245130520, prediction = Stub
# Edmond Mansoor: rev_id = 1248648606, prediction = Start
# Exequiel Bustillo: rev_id = 1188044851, prediction = Start
# Fabian Jones: rev_id = 1247632282, prediction = Stub
# Federico Helguera: rev_id = 1162056054, prediction = Start
# Germán Alfaro: rev_id = 1223272051, prediction = C
# Guillermo Francos: rev_id = 1245178482, prediction = Start
# Harold Lovell: rev_id = 1241564680, prediction = Start
# Héctor Bidonde: rev_id = 1221160348, prediction = Start
# Héctor Toty Flores: rev_id = 1067754685, prediction = Stub
# Jamale Pringle: rev_id = 1241592215, prediction = Stub
# Joanne Massiah: rev_id = 1241592526, prediction = Stub
# Joaquín Belgrano: rev_id = 1229623675, prediction = Start
# Joaquín Samuel de Anchorena: rev_id = 1227458965, prediction = Start
# Johnathan Joseph (politician): rev_id = 1241563151, prediction = Stub
# Jorge Coscia: rev_id = 1227459720, prediction = Stub
# Juan Agustín Augier: rev_id = 1217815148, prediction = Stub
# Juan Alemann: rev_id = 1227499891, prediction = Stub
# Juan Carlos Del Bello: rev_id = 1225784914, prediction = Stub
# Juan Fugl: rev_id = 1148828249, prediction = Stub
# Juan José Gómez Centurión: rev_id = 1225793565, prediction = Stub
# Kelvin Simon: rev_id = 1241592202, prediction = Start
# Kiz Johnson: rev_id = 1247632301, prediction = Stub
# Knacyntar Nedd: rev_id = 1247514093, prediction = Stub
# Luis Carlos Gómez Centurión: rev_id = 1225793589, prediction = Stub
# Luis L. Domínguez: rev_id = 1234469779, prediction = C
# Lázaro Chiappe: rev_id = 1232135530, prediction = Stub
# Manuel José García: rev_id = 1227616001, prediction = Stub
# Marco Aurelio Avellaneda: rev_id = 1233010330, prediction = Start
# Mario Cafiero: rev_id = 1135193654, prediction = Stub
# Martín Guzmán: rev_id = 1227515965, prediction = C
# Melford Nicholas: rev_id = 1241592535, prediction = Start
# Máximo Etchecopar: rev_id = 1243279888, prediction = Start
# Philip Shoul: rev_id = 1247632342, prediction = Stub
# Rawdon Turner: rev_id = 1247632346, prediction = Stub
# Rossana Chahla: rev_id = 1227517224, prediction = C
# Santiago Gallo: rev_id = 1039135531, prediction = Start
# Shawn Nicholas: rev_id = 1247632364, prediction = Stub
# Silvano Bores: rev_id = 1225775647, prediction = Stub
# Uladislao Augier: rev_id = 1217815124, prediction = Stub
# Abel Posse: rev_id = 1245068036, prediction = C
# Aldo Pignanelli: rev_id = 1106856167, prediction = Stub
# Alejo Peyret: rev_id = 1138003698, prediction = B
# Alfredo Olmedo: rev_id = 1226445117, prediction = Stub
# Amán Rawson: rev_id = 1226040049, prediction = Start
# Andrias Ghukasyan: rev_id = 1214660728, prediction = Start
# Andrés Larroque: rev_id = 1248572448, prediction = Start
# Aram Grigoryan (politician): rev_id = 1214660921, prediction = Start
# Aram Manukyan: rev_id = 1214661551, prediction = Start
# Arístides Villanueva: rev_id = 1227361697, prediction = Start
# Ashot Arsenyan: rev_id = 1218601969, prediction = C
# Carlos Kunkel: rev_id = 1225799546, prediction = Stub
# Carlos Petroni: rev_id = 1199679676, prediction = C
# Claudio Uberti: rev_id = 1245464700, prediction = C
# Enrique S. Quintana: rev_id = 1016343362, prediction = Start
# Fernando Iglesias (Argentine politician): rev_id = 1217866134, prediction = C
# Fernando Nadra: rev_id = 1238199017, prediction = C
# Gevorg Ghazaryan (politician): rev_id = 1180063729, prediction = Stub
# Gevorg Melik-Karagyozyan: rev_id = 1180063778, prediction = Stub
# Guillermo Montenegro: rev_id = 1096175549, prediction = Stub
# Gurgen Egiazaryan: rev_id = 1103745376, prediction = Start
# Hayk Chobanyan: rev_id = 1231768992, prediction = Start
# Hrant Maloyan: rev_id = 1250311867, prediction = C
# Héctor Tizón: rev_id = 1222501416, prediction = Start
# Jorge Yoma: rev_id = 1191859791, prediction = C
# Juan Mignaburu: rev_id = 1166892817, prediction = Stub
# Juan Pablo Schiavi: rev_id = 1195011460, prediction = C
# Julián de Leyva: rev_id = 1234698824, prediction = Stub
# Khachatur Malumian: rev_id = 1210493386, prediction = C
# Lucio Victorio Mansilla: rev_id = 1210433646, prediction = Start
# Marcelo Muniagurria: rev_id = 1242262794, prediction = Start
# Mariano Moreno: rev_id = 1248788227, prediction = FA
# Martín Menem: rev_id = 1247590161, prediction = Start
# Martín Sabbatella: rev_id = 1166890663, prediction = C
# Miguel Ángel Pesce: rev_id = 1211044406, prediction = Start
# Mikayel Kotanyan: rev_id = 1226313476, prediction = Start
# Mónica López (politician): rev_id = 797826672, prediction = Stub
# Nicolás Massot: rev_id = 1222899462, prediction = Start
# Norberto La Porta: rev_id = 1225799869, prediction = Stub
# Parunak Ferukhan: rev_id = 1214660598, prediction = Stub
# Ricardo Kennedy: rev_id = 1240898573, prediction = Stub
# Ruben Miroyan: rev_id = 1228290809, prediction = Start
# Ruben Mirzakhanyan: rev_id = 1214661775, prediction = Start
# Rómulo Sebastián Naón: rev_id = 1193099129, prediction = Start
# Santiago G. O'Farrell: rev_id = 1228141029, prediction = Start
# Tigran Karapetyan: rev_id = 1231946069, prediction = Start
# Tigran Khzmalyan: rev_id = 1237979345, prediction = C
# Vahagn Hovakimyan: rev_id = 1224369324, prediction = Start
# Vahan Minakhoryan: rev_id = 1214661649, prediction = Stub
# Vigen Chitechyan: rev_id = 1124301399, prediction = Stub
# Alfons Adam: rev_id = 1244617588, prediction = Start
# Andreas Hörtnagl: rev_id = 1215046038, prediction = Stub
# Anton Hofer: rev_id = 1215044432, prediction = Start
# Badal Muradyan: rev_id = 1214662146, prediction = Start
# Citizens' Ministry: rev_id = 1200893975, prediction = C
# Count Václav Antonín Chotek of Chotkov and Vojnín: rev_id = 1214682376, prediction = Start
# Eduard Hedvicek: rev_id = 1215043825, prediction = Stub
# Eduard von Grebmer zu Wolfsthurn: rev_id = 1216075327, prediction = Start
# Ernst Hampel (politician): rev_id = 1232067132, prediction = Stub
# Franz Dinghofer: rev_id = 1244619292, prediction = GA
# Franz Jetzinger: rev_id = 1214236945, prediction = Start
# Friedhelm Frischenschlager: rev_id = 1223497595, prediction = Start
# Friedrich Wilhelm von Haugwitz: rev_id = 1215043658, prediction = C
# Gabriel Noradoungian: rev_id = 1240224564, prediction = C
# Garo Paylan: rev_id = 1249622641, prediction = C
# Genrikh Poghosyan: rev_id = 1214662694, prediction = Start
# George Abraham von Dyhrn: rev_id = 1231555745, prediction = Stub
# Hans Ferlitsch: rev_id = 1240489075, prediction = Stub
# Hans Peter Haselsteiner: rev_id = 1226351964, prediction = Start
# Heinrich Alfred Barb: rev_id = 1214670404, prediction = Start
# Hermann Stern: rev_id = 1215044008, prediction = C
# Hrayr Tovmasyan: rev_id = 1243511026, prediction = Stub
# Hugo Jury: rev_id = 1225140706, prediction = C
# Ingo Appelt: rev_id = 1244447844, prediction = Stub
# Ishkhan Saghatelyan: rev_id = 1243510830, prediction = GA
# Israel Ori: rev_id = 1214986895, prediction = Start
# Joseph Buttinger: rev_id = 1214670744, prediction = Start
# Joseph Kenner: rev_id = 1169137921, prediction = Start
# Jürgen Himmelbauer: rev_id = 1215045853, prediction = Stub
# Karen Sargsyan (sociologist): rev_id = 1217803359, prediction = Start
# Kegham Vanigian: rev_id = 1214670011, prediction = Start
# Konstantin Jireček: rev_id = 1242771327, prediction = C
# Leopold Berchtold: rev_id = 1228353209, prediction = C
# Martiros Sarukhanyan: rev_id = 1214669503, prediction = Stub
# Maximilian Anton Karl, Count Baillet de Latour: rev_id = 1226152632, prediction = Start
# Michael Killisch-Horn: rev_id = 1106829544, prediction = Stub
# Narine Tukhikyan: rev_id = 1233470777, prediction = Start
# Ohannes Tchekidjian: rev_id = 1215201883, prediction = Start
# Paul Paul: rev_id = 1215924661, prediction = Start
# Prince Carl of Solms-Braunfels: rev_id = 1237091760, prediction = C
# Richard von Coudenhove-Kalergi: rev_id = 1243336388, prediction = C
# Serop Zakaryan: rev_id = 1222543352, prediction = Stub
# Sophia Kircher: rev_id = 1242552103, prediction = Stub
# Suren Shadunts: rev_id = 1242146414, prediction = Start
# Theodor Kery: rev_id = 1215046740, prediction = Stub
# Ulrich Habsburg-Lothringen: rev_id = 1216088776, prediction = Start
# Usub Bek Temuryan: rev_id = 1243494457, prediction = Stub
# Vartkes Serengülian: rev_id = 1214669611, prediction = Start
# Walter Guggenberger: rev_id = 1154443829, prediction = Start
# Alexander Zach: rev_id = 1215187552, prediction = Stub
# Aliabbas Salahzade: rev_id = 1211047878, prediction = Start
# Anton von Winzor: rev_id = 1231556425, prediction = Stub
# Brigitta Pallauf: rev_id = 1215184008, prediction = Start
# Christoph Matznetter: rev_id = 1215054758, prediction = Start
# Curt Franz Wenzel Christoph Erdmann Graf Zedtwitz von Moraván und Duppau: rev_id = 1243965585, prediction = Start
# Dilara Aliyeva: rev_id = 1236388140, prediction = Start
# Elchin Afandiyev: rev_id = 1243626881, prediction = Start
# Elmar Lichtenegger: rev_id = 1215483185, prediction = Start
# Emil Sax: rev_id = 1215185845, prediction = Start
# Enver Alikhanov: rev_id = 1161577254, prediction = Stub
# Fazail Agamali: rev_id = 1240828387, prediction = C
# Ferdinand Mannlicher: rev_id = 1250188481, prediction = C
# Franz Leitner (politician): rev_id = 1215054152, prediction = Stub
# Franz Moroder: rev_id = 1228417930, prediction = C
# Georg Adam, Prince of Starhemberg: rev_id = 1215186237, prediction = C
# Gerhard Pfanzelter: rev_id = 1238011369, prediction = Start
# Gisela Wurm: rev_id = 1215187415, prediction = Stub
# Gottfried von Kühnelt-Leddihn: rev_id = 1235730032, prediction = Start
# Gregor Razumovsky (activist): rev_id = 1236098636, prediction = C
# Gundaker Thomas Starhemberg: rev_id = 1246777408, prediction = Start
# Heidemaria Onodi: rev_id = 1246630894, prediction = Start
# Heinz Nittel: rev_id = 1226214871, prediction = Stub
# Horst Rosenkranz: rev_id = 1215185628, prediction = Start
# Hubert Klausner: rev_id = 1242810704, prediction = Start
# Johann Anton von Pergen: rev_id = 1248404055, prediction = C
# Johann Gregor Memhardt: rev_id = 1226209962, prediction = Stub
# Josef Staribacher: rev_id = 1215186443, prediction = Stub
# Julius Lippert (historian): rev_id = 1248432097, prediction = Stub
# Julius Tandler: rev_id = 1153989705, prediction = Start
# Józef Kożdoń: rev_id = 1215053905, prediction = C
# Jürgen Mandl: rev_id = 1215054486, prediction = Stub
# Karl Freiherr von Vogelsang: rev_id = 1231556362, prediction = Start
# Karl Lütgendorf: rev_id = 1231556108, prediction = Stub
# Karl Schmitzer: rev_id = 1215186109, prediction = Stub
# Karl von Zinzendorf: rev_id = 1240906258, prediction = Start
# Leopold, Count von Thun und Hohenstein: rev_id = 1215186791, prediction = C
# Leopold Poetsch: rev_id = 1248552155, prediction = Start
# Leyla Abdullayeva: rev_id = 1230366514, prediction = Start
# Martin Kocher: rev_id = 1241392879, prediction = Stub
# Muzamil Abdullayev: rev_id = 1223484511, prediction = Stub
# Peter Schieder: rev_id = 1239601735, prediction = Start
# Peter Strasser (politician): rev_id = 1240951343, prediction = Start
# Reinhold Lopatka: rev_id = 1240127163, prediction = Stub
# Renate Mann: rev_id = 1099978355, prediction = Stub
# Sonja Zwazl: rev_id = 1235856770, prediction = Start
# Tarlan Aliyarbayov: rev_id = 1240965677, prediction = GA
# Thomas Prinzhorn: rev_id = 1215185462, prediction = C
# Walter Pfrimer: rev_id = 1249288737, prediction = C
# Wladimir von Pawlowski: rev_id = 1242446030, prediction = Stub
# Abdurrahman Fatalibeyli: rev_id = 1241052691, prediction = C
# Afshan Gadimbeyova: rev_id = 1243747432, prediction = Start
# Ahmad Kordary: rev_id = 1187254621, prediction = Stub
# Ajdar Ismailov: rev_id = 1157124148, prediction = C
# Akram Aylisli: rev_id = 1247420701, prediction = C
# Ali Asadov: rev_id = 1237483914, prediction = C
# Ali Huseynli: rev_id = 1245270394, prediction = Start
# Ali Ibrahimov: rev_id = 1244157806, prediction = Start
# Ali M. Hasanov: rev_id = 1245282668, prediction = C
# Alisahib Huseynov: rev_id = 1246588423, prediction = Start
# Alovsat Bakhshiyev: rev_id = 1207738330, prediction = Start
# Anar Karimov: rev_id = 1245270299, prediction = Start
# Arastun Javadov: rev_id = 1147579900, prediction = Stub
# Araz Alizadeh: rev_id = 1246060446, prediction = Stub
# Asaf Hajiyev: rev_id = 1235219197, prediction = C
# Ashraf Bey Taghiyev: rev_id = 1213943020, prediction = Start
# Bakhish bey Rustambeyov: rev_id = 1246060690, prediction = Start
# Boris Kevorkov: rev_id = 1217681945, prediction = Start
# Chimnaz Aslanova: rev_id = 1245503366, prediction = Start
# Farhad Hajiyev: rev_id = 1246286594, prediction = Start
# Fazail Ibrahimli: rev_id = 1243509483, prediction = Start
# Garib Karimoğlu: rev_id = 1246060699, prediction = Start
# Gudrat Gasanguliev: rev_id = 1234004989, prediction = Start
# Gurban Khalilov: rev_id = 1243520102, prediction = Start
# Haji Molla Ahmad Nuruzade: rev_id = 1239189558, prediction = GA
# Hasan Hasanli: rev_id = 1244589428, prediction = Start
# Hasan Majidov: rev_id = 1236490430, prediction = Start
# Huseyngulu Baghirov: rev_id = 1199215674, prediction = Start
# Ilham Madatov: rev_id = 1011331249, prediction = Start
# Irshad Aliyev: rev_id = 1225308278, prediction = Stub
# Jamil Hasanli: rev_id = 1248447237, prediction = C
# Jeyhun Jalilov: rev_id = 1228687346, prediction = Start
# Lutfali bey Behbudov: rev_id = 1226230854, prediction = C
# Majnun Mammadov: rev_id = 1248225337, prediction = Start
# Makhmud Mamed-Guliev: rev_id = 1243510539, prediction = Start
# Mamed Iskenderov: rev_id = 1244201378, prediction = Start
# Mammad Gurbanov: rev_id = 1237445893, prediction = Start
# Mirgasim Cheshmazer: rev_id = 1226415908, prediction = Start
# Musa Hacigasimov: rev_id = 1236490449, prediction = Stub
# Musa Mammadov: rev_id = 1243510550, prediction = Start
# Ramin Mammadov: rev_id = 1248662299, prediction = Start
# Rovshan Javadov: rev_id = 1250266366, prediction = C
# Saftar Jafarov: rev_id = 1222623261, prediction = Start
# Sahil Babayev: rev_id = 1207600921, prediction = C
# Solomon Grobshtein: rev_id = 1067081975, prediction = Stub
# Teymur Guliyev: rev_id = 1232296078, prediction = Stub
# Vidadi Isgandarov: rev_id = 1249203876, prediction = Start
# Vilayat Eyvazov: rev_id = 1208072134, prediction = Start
# Zakir Hasanov: rev_id = 1224596001, prediction = C
# Abdulla Adel Fakhro: rev_id = 1223700072, prediction = Start
# Abdullah bin Isa Al Khalifa: rev_id = 1182830303, prediction = Start
# Abid Sharifov: rev_id = 1243510547, prediction = Start
# Ahmed Behzad (Bahrain): rev_id = 1063482737, prediction = Stub
# Ammar Al Bannai: rev_id = 1231654401, prediction = Start
# Aymen Tawfeeq Almoayed: rev_id = 1227286508, prediction = Start
# Bakhtiyar Vahabzadeh: rev_id = 1249675761, prediction = C
# Charles Carter (Bahamian journalist): rev_id = 1162793449, prediction = C
# Eldar Namazov: rev_id = 1206211739, prediction = Start
# Elshad Mirbashir oghlu: rev_id = 1194162044, prediction = C
# Eugene Dupuch: rev_id = 1181612386, prediction = Start
# Faisal al-Hamar: rev_id = 1218302538, prediction = Stub
# Fuad Naghiyev: rev_id = 1248662296, prediction = Start
# Harold Christie: rev_id = 1142294843, prediction = Start
# Hasan Seyidov: rev_id = 1148385245, prediction = Stub
# Hasan Seyidov (scientist): rev_id = 1198202282, prediction = Start
# Huseyn Rahmanov: rev_id = 1106104383, prediction = Stub
# Ikhtiyar Shirinov: rev_id = 1243510572, prediction = Stub
# Isa bin Abdulrahman Al Hammadi: rev_id = 1098344827, prediction = Stub
# Isa bin Ibrahim Al Khalifa: rev_id = 1146485875, prediction = Stub
# Jameel Humadan: rev_id = 1148959062, prediction = Start
# James Carmichael Smith (postmaster): rev_id = 1248344476, prediction = C
# Jawad Fairooz: rev_id = 1177286981, prediction = Start
# Joseph Robert Love: rev_id = 1177467150, prediction = C
# Kamal Ahmed (politician): rev_id = 1215486840, prediction = Stub
# Keith Bell (Bahamian politician): rev_id = 1243023554, prediction = Start
# Khalid Almoayed: rev_id = 1215466172, prediction = Stub
# Mahmood Al Bahrani: rev_id = 1161492589, prediction = Stub
# Mammad agha Shahtakhtinski: rev_id = 1185599926, prediction = C
# McKell Bonaby: rev_id = 1238577650, prediction = Stub
# Mohamed Ali Hasan Ali: rev_id = 1006173162, prediction = Stub
# Mohammed Isa Al Abbasi: rev_id = 1171757402, prediction = Stub
# Movsum Samadov: rev_id = 1241255046, prediction = C
# Nabeel bin Yaqub Al-Hamar: rev_id = 1159628135, prediction = Stub
# Namig Nasrullayev: rev_id = 1158375491, prediction = Stub
# Nazar Al Baharna: rev_id = 1241906132, prediction = Start
# Nurali Yusifbayli: rev_id = 1243510541, prediction = Start
# Pakesia Parker-Edgecombe: rev_id = 1226025677, prediction = Start
# Parviz Shahbazov: rev_id = 1213858589, prediction = Start
# Qasim Fakhro: rev_id = 1099067663, prediction = Start
# Rovshen Rzayev: rev_id = 1208078338, prediction = Start
# Sadig Rahimov: rev_id = 1245157534, prediction = C
# Shirali Akhundov: rev_id = 1213002608, prediction = C
# Siyavush Novruzov: rev_id = 1243520070, prediction = C
# Suleyman Rahimov: rev_id = 1193027962, prediction = C
# Tahir Mirkishili: rev_id = 1210593900, prediction = Start
# Timothy Donaldson: rev_id = 1245586658, prediction = C
# Vugar Mustafayev (minister): rev_id = 1208077047, prediction = Start
# Yusif Ziya Talibzadeh: rev_id = 1243510546, prediction = GA
# Zahid Oruj: rev_id = 1213965350, prediction = Start
# AKM Fazlul Kabir Chowdhury: rev_id = 1245380545, prediction = Start
# AKM Hafizuddin: rev_id = 1246694478, prediction = Stub
# Abdul Motaleb: rev_id = 1245374567, prediction = Stub
# Abdulhussain bin Ali Mirza: rev_id = 1195787872, prediction = Stub
# Abdulla Hassan Saif: rev_id = 1219928150, prediction = Stub
# Abdullah bin Hamad bin Isa Al Khalifa: rev_id = 1241499929, prediction = Start
# Abdullatif Al-Mahmood: rev_id = 1227285970, prediction = Stub
# Abdulrahman al-Nuaimi: rev_id = 1235804624, prediction = Start
# Abdus Salam (Chattogram politician): rev_id = 1245374007, prediction = Stub
# Abul Hashim: rev_id = 1232200030, prediction = C
# Ahmed Al-Salloum: rev_id = 1244755894, prediction = Start
# Ahmed bin Mohamed Al Khalifa: rev_id = 1221144846, prediction = Stub
# Ali bin Khalifa Al Khalifa: rev_id = 1229583096, prediction = Stub
# Ali bin Saleh Al Saleh: rev_id = 1239617504, prediction = Stub
# Aminul Islam Chowdhury: rev_id = 1175807916, prediction = Start
# Aminul Islam Rabel: rev_id = 1245379837, prediction = Stub
# Ammar Qambar: rev_id = 1140605737, prediction = Start
# Anwarul Karim Chowdhury: rev_id = 1245395466, prediction = C
# Ashab Uddin Ahmad: rev_id = 1245380479, prediction = B
# Birendra Kishore Roaza: rev_id = 1246126702, prediction = Stub
# Bishnu Chattopadhyay: rev_id = 1242147738, prediction = Start
# Chowdhury Shamsuddin Ahmed: rev_id = 1237261756, prediction = Stub
# Essam Khalaf: rev_id = 1006167519, prediction = Stub
# Fahmi al-Jowder: rev_id = 1172576081, prediction = Stub
# Farid Ahmed: rev_id = 1245375794, prediction = Stub
# Hala bint Mohammed Al Khalifa: rev_id = 1232948277, prediction = Start
# Hamad Al Kooheji: rev_id = 1233118749, prediction = Stub
# Ibrahim ibn Khalifa Al Khalifa: rev_id = 1156409493, prediction = Start
# Isa Qassim: rev_id = 1249444464, prediction = GA
# Khalid Al Maskati: rev_id = 1209519423, prediction = Stub
# M Hossain Ali: rev_id = 1242815841, prediction = Start
# Mai bint Mohammed Al Khalifa: rev_id = 1217876419, prediction = Start
# Mohammad A. Arafat: rev_id = 1250294465, prediction = GA
# Mohammad Manjur Alam: rev_id = 1245377984, prediction = Start
# Mohammed Al-Buainain: rev_id = 1063213013, prediction = Start
# Mohammed bin Khalifa bin Ahmed: rev_id = 1244455253, prediction = C
# Mohammed bin Khalifa bin Ali Al Khalifa: rev_id = 1202322111, prediction = Start
# Moinuddin Ahmed Chowdhury: rev_id = 1166369458, prediction = C
# Muzaffar Ahmed (NAP politician): rev_id = 1245380189, prediction = Start
# Nurul Huq Bhuiyan: rev_id = 1236303322, prediction = Stub
# Oli Ahad: rev_id = 1247061966, prediction = Start
# Rasheed Mohammed Al Maraj: rev_id = 1247375502, prediction = Stub
# Salman bin Hamad Al Khalifa: rev_id = 1250494329, prediction = C
# Salman bin Khalifa Al Khalifa: rev_id = 1247375519, prediction = Stub
# Sarwar Jan Chowdhury: rev_id = 1245377291, prediction = Stub
# Saud Kanoo: rev_id = 1098699647, prediction = Stub
# Selina Banu: rev_id = 1183475136, prediction = Start
# Shafiqur Rahman Badsha: rev_id = 1245374148, prediction = Stub
# Shahinur Pasha Chowdhury: rev_id = 1245379554, prediction = Start
# Yusuf Ali Chowdhury: rev_id = 1228415190, prediction = Start
# AKM Fazlul Haque (Jatiya Party politician): rev_id = 1245402550, prediction = Stub
# Abdul Halim Ghaznavi: rev_id = 1237265302, prediction = Start
# Abdur Rahim (scholar): rev_id = 1250046255, prediction = C
# Abul Kalam Shamsuddin: rev_id = 1246347372, prediction = Start
# Abul Kashem: rev_id = 1232782976, prediction = C
# Abul Kashem Khan: rev_id = 1245380771, prediction = C
# Asheq Ullah Rafiq: rev_id = 1245374666, prediction = Stub
# Badruddin Umar: rev_id = 1220769997, prediction = C
# Badruddoza Ahmed Shuja: rev_id = 1245376617, prediction = Stub
# Debendra Nath Ghosh: rev_id = 1240939624, prediction = Stub
# Devasish Roy: rev_id = 1247376048, prediction = Start
# Elliott Belgrave: rev_id = 1242611945, prediction = Start
# Fazlul Haque Montu: rev_id = 1243563371, prediction = Stub
# Ferdous Ahmed Qureshi: rev_id = 1246263516, prediction = Start
# Golam Maula Rony: rev_id = 1246686682, prediction = Start
# Habibar Rahman: rev_id = 1245395381, prediction = Stub
# Haji Mohammad Danesh: rev_id = 1230176939, prediction = C
# Hatem Ali Khan: rev_id = 1237261567, prediction = Start
# Husam Uddin Chowdhury Fultali: rev_id = 1247693188, prediction = Start
# James Leo Ferguson: rev_id = 1212687396, prediction = C
# Jyotirindra Bodhipriya Larma: rev_id = 1247242676, prediction = Stub
# Kazi Abdus Shahid Lal: rev_id = 1237261507, prediction = Start
# M. Anwar Hossain: rev_id = 1226325755, prediction = C
# M. M. Rahmatullah: rev_id = 1242580877, prediction = C
# Mahmudul Haque Sayem: rev_id = 1250491967, prediction = Stub
# Manik Lal Ray: rev_id = 1117752666, prediction = Stub
# Manjurul Imam: rev_id = 1245961260, prediction = Stub
# Maulana Shakhawat: rev_id = 1067136662, prediction = Stub
# Mohammad Sultan: rev_id = 1237264157, prediction = Start
# Mohammad Toaha: rev_id = 1046006361, prediction = Start
# Mohammad Zillur Rahman: rev_id = 1245374883, prediction = Start
# Moin Uddin (politician): rev_id = 1245374542, prediction = Stub
# Muhammad Bayazeed Khan Panni: rev_id = 1225060231, prediction = C
# Muhammad Hamidullah Khan: rev_id = 1249497016, prediction = C
# Mujahidul Islam Selim: rev_id = 1241208220, prediction = Start
# Mujibur Rahman (Chattogram politician): rev_id = 1245374586, prediction = Stub
# Mushrefa Mishu: rev_id = 1066093324, prediction = Start
# Nozir Hossain: rev_id = 1245378724, prediction = Start
# Pulin De: rev_id = 1242126632, prediction = Start
# Ranesh Das Gupta: rev_id = 1242257552, prediction = Start
# SM Nuruzzaman: rev_id = 1246459927, prediction = Stub
# Shafiul Alam Chowdhury Nadel: rev_id = 1245978368, prediction = Start
# Shamima Harun Lubna: rev_id = 1245374454, prediction = Stub
# Shamsul Huda Panchbagi: rev_id = 1232199873, prediction = B
# Sourendra Nath Chakraborty: rev_id = 1245374793, prediction = Start
# Syed Muhammad Ibrahim: rev_id = 1247089625, prediction = Start
# Syed Najmuddin Hashim: rev_id = 1245394398, prediction = Start
# Syed Sayedul Haque Suman: rev_id = 1247669907, prediction = Start
# Yar Mohammad Khan: rev_id = 1244156514, prediction = C
# Zahidunnabi Dewan Shamim: rev_id = 1237263822, prediction = Start
# Adrian Forde: rev_id = 1079840895, prediction = Stub
# Alaksandar Dubko: rev_id = 1173907794, prediction = Stub
# Aleksandr Potupa: rev_id = 1235204307, prediction = C
# Alexander Radkov: rev_id = 1216932338, prediction = Start
# Aliaksandr Azarau: rev_id = 1249779544, prediction = GA
# Anatoĺ Kalinin: rev_id = 1224032323, prediction = Start
# Chad Blackman: rev_id = 1239861059, prediction = Start
# Charles Duncan O'Neal: rev_id = 1236388821, prediction = Start
# Colin Everett Jordan: rev_id = 1090593974, prediction = Stub
# Crystal Haynes: rev_id = 1219669780, prediction = Stub
# Cynthia Y. Forde: rev_id = 1200176178, prediction = Start
# Damien K. A. Griffith: rev_id = 1123730836, prediction = Stub
# Davidson Ishmael: rev_id = 1123554066, prediction = Stub
# Dwight Sutherland: rev_id = 1226875792, prediction = Stub
# Gennady Grushevoy: rev_id = 1225610619, prediction = C
# Glyne Murray: rev_id = 1218309623, prediction = Stub
# Ian Gooding-Edghill: rev_id = 1245455194, prediction = Stub
# Ivan Kubrakov: rev_id = 1243510259, prediction = Start
# Jan Pazniak: rev_id = 1246821242, prediction = Stub
# John Andrew King: rev_id = 1191591712, prediction = Start
# Kerrie Symmonds: rev_id = 1226922424, prediction = Start
# Kirk Matthew Humphrey: rev_id = 1079886049, prediction = Stub
# Lyavon Barshchewski: rev_id = 1237691839, prediction = Stub
# Michael A. Carrington: rev_id = 1090468579, prediction = Start
# Moshe Gutman: rev_id = 1226775102, prediction = Stub
# Philip St. Hill: rev_id = 1132713774, prediction = Stub
# Pyotr Prakapovich: rev_id = 1228551886, prediction = Stub
# Reginald Farley: rev_id = 1223215475, prediction = Stub
# Ryan Straughn: rev_id = 1232133512, prediction = Stub
# Samuel Jackman Prescod: rev_id = 1227284229, prediction = C
# Santia Bradshaw: rev_id = 1225635388, prediction = Start
# Shanika Roberts-Odle: rev_id = 1126117422, prediction = Stub
# Shantal Munro-Knight: rev_id = 1248634872, prediction = Stub
# Siamion Domash: rev_id = 1245495829, prediction = Stub
# Siarhei Cherachen: rev_id = 1177364352, prediction = Start
# Sonia Browne: rev_id = 1080633319, prediction = Stub
# Symon Rak-Michajłoŭski: rev_id = 1216629323, prediction = GA
# Tadeusz Kościuszko: rev_id = 1250431981, prediction = FA
# Tamaš Hryb: rev_id = 1217471500, prediction = C
# Tsimafei Dranchuk: rev_id = 1115164729, prediction = Start
# Uladzimir Mackievič: rev_id = 1249602665, prediction = C
# Uładzimir Hančaryk: rev_id = 1105545058, prediction = Stub
# Uładzisłau Kazłouski: rev_id = 1205140753, prediction = Start
# V. L. Mukha: rev_id = 1144551736, prediction = Stub
# Valery Levaneuski: rev_id = 1248009248, prediction = C
# Vladimir Kumets: rev_id = 1147914902, prediction = C
# Voĺha Karač: rev_id = 1234751055, prediction = C
# William Fondleroy Duguid: rev_id = 1149070233, prediction = Start
# Yury Ambrazevich: rev_id = 1172992483, prediction = Stub
# Zmitser Dashkevich: rev_id = 1244903816, prediction = Start
# Aleksandr Turchin: rev_id = 1245495069, prediction = Stub
# Aliaksandr Shakutsin: rev_id = 1246263655, prediction = C
# Antoine Brun: rev_id = 1179322005, prediction = Start
# August De Boodt: rev_id = 1140361651, prediction = Start
# Auguste Couvreur: rev_id = 1058540061, prediction = Stub
# Dirk De fauw: rev_id = 1248580125, prediction = Start
# Dominik Semashko: rev_id = 1214790691, prediction = GA
# Edward Woyniłłowicz: rev_id = 1244677659, prediction = B
# Eugène Goblet d'Alviella: rev_id = 1182389599, prediction = Start
# Fernand Cocq: rev_id = 1243330963, prediction = Stub
# Frank Beke: rev_id = 1161024456, prediction = Stub
# François-Philippe de Haussy: rev_id = 1233546471, prediction = Stub
# Françoise Dupuis: rev_id = 1224617580, prediction = Stub
# Gustave Boël: rev_id = 1233502726, prediction = Start
# Guy Hance: rev_id = 1217126753, prediction = Stub
# Herman Baltia: rev_id = 1231554975, prediction = Start
# Ihar Rynkevich: rev_id = 1064451133, prediction = C
# Ivan Yermachenka: rev_id = 1243935880, prediction = Start
# Jacques Grippa: rev_id = 1226329636, prediction = Stub
# Jan Béghin: rev_id = 1243748019, prediction = Start
# Jan Stankievič: rev_id = 1245626600, prediction = Start
# Jean-Pierre Grafé: rev_id = 1112290249, prediction = Stub
# Joris Helleputte: rev_id = 1051591828, prediction = Start
# Jos Dupré: rev_id = 1249790591, prediction = Stub
# José Desmarets: rev_id = 1225811527, prediction = Stub
# Jules Hiernaux: rev_id = 1194388133, prediction = Stub
# Julien Goekint: rev_id = 1149315537, prediction = Start
# Julius Hoste Jr.: rev_id = 1215066294, prediction = Start
# Lucienne Herman-Michielsens: rev_id = 1235711895, prediction = Start
# Manuel Abramowicz: rev_id = 1243531072, prediction = Stub
# Marc Drumaux: rev_id = 1054937431, prediction = Start
# Marcel de Baer: rev_id = 1221734112, prediction = C
# Mikola Statkevich: rev_id = 1243221482, prediction = GA
# Nico Cué: rev_id = 1226437075, prediction = Start
# Nikolai Shelyagovich: rev_id = 1206663730, prediction = Start
# Norbert De Cuyper: rev_id = 1165947877, prediction = Start
# Norbert Hougardy: rev_id = 1139979372, prediction = Stub
# Pierre David (mayor): rev_id = 1244830798, prediction = GA
# Pol Clovis Boël: rev_id = 1233502703, prediction = Start
# René De Feyter: rev_id = 1165734903, prediction = Stub
# Rudy Aernoudt: rev_id = 1241935456, prediction = C
# Sergei Tikhanovsky: rev_id = 1247883595, prediction = C
# Valery Sakhashchyk: rev_id = 1241105852, prediction = B
# Veerle Geerinckx: rev_id = 1246136139, prediction = Start
# Victor de Laveleye: rev_id = 1173454330, prediction = Start
# Vladimir Rusakevich: rev_id = 1236837678, prediction = Start
# Yury Voskresensky: rev_id = 1173778739, prediction = C
# Édouard Descamps: rev_id = 1231555121, prediction = Start
# Émile Coulonvaux: rev_id = 1222825457, prediction = Stub
# Émile van Dievoet: rev_id = 1202217968, prediction = C
# Adolphe Van Glabbeke: rev_id = 1224501115, prediction = Start
# Ahmet Koç (politician): rev_id = 1243748075, prediction = Start
# Alexander Albert Hunter: rev_id = 1247370963, prediction = Start
# Alfons Siffer: rev_id = 1044386557, prediction = Start
# André-Eugène Pirson: rev_id = 1233498632, prediction = Start
# André Kempinaire: rev_id = 1198582609, prediction = Stub
# André Molitor: rev_id = 1190357309, prediction = Start
# Arnauld Antoine Akodjènou: rev_id = 1170437413, prediction = C
# Basilio Ah: rev_id = 1242446129, prediction = Stub
# Bert Tucker: rev_id = 1215561378, prediction = C
# Beverly Castillo: rev_id = 1171859695, prediction = Stub
# Charles Bartlett Hyde: rev_id = 1247370983, prediction = Start
# Cyrille Tahay: rev_id = 1244463135, prediction = Stub
# Dorah Ilunga: rev_id = 1183327367, prediction = Start
# Elfreda Reyes: rev_id = 1225001639, prediction = C
# Father Samuel: rev_id = 1249920109, prediction = C
# Fientje Moerman: rev_id = 1229904524, prediction = Start
# Gaëtan Van Goidsenhoven: rev_id = 1227001179, prediction = C
# Georges Kaeckenbeeck: rev_id = 1212308026, prediction = Start
# Glenn Godfrey: rev_id = 1239031792, prediction = Start
# Gustave Rolin-Jaequemyns: rev_id = 1236873042, prediction = C
# ...
# Serhii Shapran: rev_id = 1249146625, prediction = C
# Serhiy Tymchenko: rev_id = 1249574861, prediction = Start
# Taras Tarasenko: rev_id = 1194398452, prediction = Start
# Vasyl Poraiko: rev_id = 1213107063, prediction = Start
# Viacheslav Suprunenko: rev_id = 1146431478, prediction = Start
# Vitalii Kurylo: rev_id = 1179344499, prediction = C
# Vladimir Saldo: rev_id = 1250298214, prediction = GA
# Volodymyr Matvienko: rev_id = 1230557950, prediction = GA
# Volodymyr Petrov: rev_id = 1244845824, prediction = GA
# Volodymyr Serhiychuk: rev_id = 1179345129, prediction = Start
# Volodymyr Stelmakh: rev_id = 1249875856, prediction = Start
# Volodymyr Tsvil: rev_id = 1232601928, prediction = C
# Volodymyr Tyahlo: rev_id = 1179346831, prediction = Start
# Vyacheslav Shapovalov: rev_id = 1183782262, prediction = Stub
# Yelena Protsenko: rev_id = 1243514438, prediction = Start
# Yurii Lavreniuk: rev_id = 1204238271, prediction = Start
# Yuriy Vozniuk: rev_id = 1179848407, prediction = Start
# Abdusalom Azizov: rev_id = 1246468761, prediction = Start
# Adham Ahmedbaev: rev_id = 1247704434, prediction = Start
# Antonio Mercader: rev_id = 1193060468, prediction = Start
# Carlos Pita (politician): rev_id = 1225819287, prediction = Start
# Carlos Quijano: rev_id = 1172801438, prediction = Stub
# Dámaso Antonio Larrañaga: rev_id = 1209913980, prediction = Stub
# Edgardo Novick: rev_id = 1232110434, prediction = Stub
# Eduardo Lorier: rev_id = 1238776852, prediction = Stub
# Enrique Pintado: rev_id = 1229665135, prediction = Stub
# Erkin Khalilov: rev_id = 1242468179, prediction = Stub
# Florencio Sánchez: rev_id = 1244429745, prediction = C
# Gonzalo Nin Novoa: rev_id = 1106146731, prediction = Stub
# Guido Manini Ríos: rev_id = 1235341731, prediction = C
# Guillermo Chifflet: rev_id = 1140500454, prediction = Stub
# Guillermo Domenech: rev_id = 1236521270, prediction = Start
# Hector Luisi: rev_id = 1192169906, prediction = Start
# Ikhtiyor Abdullayev: rev_id = 1247702597, prediction = Start
# Isidoro de María: rev_id = 1248513982, prediction = Stub
# Jakhongir Artikkhodjayev: rev_id = 1230521779, prediction = C
# Jorge Bruni: rev_id = 1101182986, prediction = Stub
# Jorge Zabalza: rev_id = 1232110666, prediction = Start
# José Benito Monterroso: rev_id = 1225811185, prediction = Stub
# José Brito del Pino: rev_id = 1231236699, prediction = C
# José Pedro Varela: rev_id = 1184349404, prediction = Stub
# José Rondeau: rev_id = 1229765194, prediction = Start
# Juan Francisco Larrobla: rev_id = 1159863480, prediction = Stub
# Karim Kamalov: rev_id = 1247703243, prediction = Start
# Laura Cortinas: rev_id = 1241843549, prediction = Start
# Laura Raffo: rev_id = 1232440725, prediction = C
# Liliam Kechichián: rev_id = 1239924729, prediction = Start
# Lorenzo Antonio Fernández: rev_id = 1225789614, prediction = Stub
# Luis Almagro: rev_id = 1246000343, prediction = B
# Luis Melián Lafinur: rev_id = 946357029, prediction = Start
# María Inés Obaldía: rev_id = 1227581396, prediction = Start
# Mateo Vidal: rev_id = 1093592713, prediction = Stub
# Mónica Bottero: rev_id = 1158316569, prediction = Start
# Pablo Mieres: rev_id = 1234857670, prediction = Start
# Pedro Figari: rev_id = 1237875130, prediction = C
# Pedro Vaz (diplomat): rev_id = 1108530199, prediction = Stub
# Rashid Kadyrov: rev_id = 1247702823, prediction = C
# Rustam Inoyatov: rev_id = 1247702441, prediction = Start
# Sa'dulla Begaliyev: rev_id = 1247704310, prediction = Stub
# Sebastián Bauzá: rev_id = 1237709578, prediction = Start
# Sherzodkhon Kudratkhuja: rev_id = 1214067513, prediction = Start
# Tatyana Karimova: rev_id = 1245927956, prediction = C
# Tristán Narvaja: rev_id = 1206959075, prediction = Start
# Uktam Barnoev: rev_id = 1224037855, prediction = Start
# Valery Ataev: rev_id = 1205273470, prediction = Stub
# Vitaly Zholobov: rev_id = 1243513404, prediction = C
# Yamandú Orsi: rev_id = 1250416713, prediction = GA
# Alberto Franceschi: rev_id = 1198782364, prediction = Start
# Alejandra Benítez: rev_id = 1246651957, prediction = Start
# Alí Domínguez: rev_id = 1240451011, prediction = C
# Américo Martín: rev_id = 1246354258, prediction = Stub
# Andrés Izarra: rev_id = 1246246457, prediction = Start
# Arnoldo Gabaldón: rev_id = 1216357280, prediction = C
# Bahrom Norqobilov: rev_id = 1219558071, prediction = Start
# Bakhodir Khan Turkistan: rev_id = 1192709223, prediction = B
# Bakhodir Kurbanov (general): rev_id = 1220771041, prediction = Start
# Baxtiyor Rahimov: rev_id = 1248651514, prediction = Start
# Bekjon Rakhmonov: rev_id = 1226100587, prediction = Start
# Boʻritosh Mustafoyev: rev_id = 1157984320, prediction = Stub
# Buenaventura Macabeo Maldonado Vivas: rev_id = 1231707762, prediction = C
# Carlos Augusto León: rev_id = 1232115163, prediction = Start
# César González Martínez: rev_id = 1218574777, prediction = C
# Dia Nader de El-Andari: rev_id = 1243220418, prediction = Start
# Dinh Van Than: rev_id = 1244170639, prediction = C
# Felix Díaz Ortega: rev_id = 1202899562, prediction = Start
# Fernando Adames Torres: rev_id = 1217851956, prediction = Start
# Fidel Barbarito: rev_id = 1246246398, prediction = Stub
# Francisco de Miranda: rev_id = 1247134615, prediction = B
# Franklyn Duarte: rev_id = 1246246730, prediction = Start
# Freddy Ñáñez: rev_id = 1246246481, prediction = Stub
# Ivonne Attas: rev_id = 1250286831, prediction = Start
# Jahangir Mamatov: rev_id = 1158281467, prediction = C
# Jimmy Stevens (politician): rev_id = 1169502061, prediction = Start
# Jorge Elieser Márquez: rev_id = 1219284052, prediction = Start
# Jorge Giordani: rev_id = 1246246427, prediction = C
# José Bernabé Gutiérrez: rev_id = 1218120878, prediction = Start
# José Brito (politician): rev_id = 1246246718, prediction = C
# José Curiel: rev_id = 1226437176, prediction = Stub
# Liborio Guarulla: rev_id = 1242552557, prediction = C
# Luis Graterol Caraballo: rev_id = 1248971751, prediction = Stub
# María Cristina Iglesias: rev_id = 1246246447, prediction = Stub
# Moisés Naím: rev_id = 1247919584, prediction = C
# Narzullo Oblomurodov: rev_id = 1247703142, prediction = C
# Nelson Martínez (politician): rev_id = 1246246463, prediction = Stub
# Pedro Bastidas: rev_id = 1232135029, prediction = Start
# President of Vanuatu: rev_id = 1211211712, prediction = Start
# Qobul Tursunov: rev_id = 1213407495, prediction = Stub
# Ramón Lobo (economist): rev_id = 1246246763, prediction = Start
# Ravshanbek Qurbonov: rev_id = 1248998037, prediction = Start
# Reinaldo Iturriza: rev_id = 1246246455, prediction = Stub
# Reinaldo Leandro Mora: rev_id = 1195139267, prediction = Start
# Reinaldo Muñoz Pedroza: rev_id = 1189619482, prediction = Stub
# Rimajon Xudoyberganova: rev_id = 1242391949, prediction = C
# Rubén González Cárdenas: rev_id = 1240178755, prediction = C
# Vicente José Gregorio Díaz Silva: rev_id = 1242413774, prediction = Start
# Vincent Lunabek: rev_id = 1132674478, prediction = Stub
# Vladimir Gessen (Venezuelan politician): rev_id = 1225792818, prediction = Stub
# Addy Valero: rev_id = 1246247019, prediction = Start
# Alejandro Peña Esclusa: rev_id = 1247050566, prediction = C
# Arkiely Perfecto: rev_id = 1246246976, prediction = Start
# Benjamín Rausseo: rev_id = 1246857158, prediction = Start
# Bolivia Suárez: rev_id = 1246247008, prediction = Stub
# Bùi Tiến Dũng (politician): rev_id = 1209293575, prediction = Stub
# Carlos Eduardo Stolk: rev_id = 1245089053, prediction = Start
# Carlos Santana Tovar: rev_id = 1242453867, prediction = Start
# Chu Văn An: rev_id = 1244809536, prediction = Start
# Eduardo Piñate: rev_id = 1246246484, prediction = Start
# Gustavo Tarre: rev_id = 1245587280, prediction = GA
# Henry Ventura: rev_id = 1246246808, prediction = Stub
# Hoang Van Chi: rev_id = 1249314533, prediction = C
# Hoàng Cao Khải: rev_id = 1241426352, prediction = Stub
# Humberto Prado: rev_id = 1097454386, prediction = Start
# Huỳnh Văn Cao: rev_id = 1233300105, prediction = C
# Hồ Văn Nhựt: rev_id = 1238255201, prediction = C
# Hồ Đắc Điềm: rev_id = 1193882673, prediction = Stub
# José Antonio Velutini: rev_id = 1135427671, prediction = Start
# José Herrera Uslar: rev_id = 1153086780, prediction = Start
# Kiem Do: rev_id = 1238520532, prediction = Start
# Kiều Mộng Thu: rev_id = 1242490895, prediction = Start
# Lewis Pérez: rev_id = 1232134166, prediction = Start
# Lê Minh Hương: rev_id = 1226261855, prediction = Stub
# Lê Quốc Minh: rev_id = 1241039136, prediction = C
# Lê Văn Thành: rev_id = 1226261978, prediction = Stub
# Lương Thế Huy: rev_id = 1247377913, prediction = Stub
# Manuel Felipe Rugeles: rev_id = 1208177120, prediction = Start
# Miguel Peña (politician): rev_id = 1228343895, prediction = Stub
# Milena Sardi de Selle: rev_id = 1145661230, prediction = Stub
# Nervis Villalobos: rev_id = 1201838885, prediction = C
# Nguyễn Duy Quý: rev_id = 1245479331, prediction = Stub
# Nguyễn Dương Đôn: rev_id = 1177240282, prediction = Stub
# Nguyễn Hồng Diên: rev_id = 1237710183, prediction = C
# Nguyễn Hợp Đoàn: rev_id = 1232872822, prediction = Start
# Nguyễn Phan Long: rev_id = 1221992596, prediction = Start
# Nguyễn Quốc Cường: rev_id = 1130925190, prediction = Stub
# Nguyễn Quốc Định: rev_id = 1221993606, prediction = C
# Nguyễn Thị Hồng (economist): rev_id = 1214023850, prediction = Start
# Nguyễn Thị Thập: rev_id = 1145703738, prediction = Start
# Nguyễn Văn Huyền: rev_id = 1241609893, prediction = C
# Nguyễn Văn Lực: rev_id = 1106652276, prediction = Stub
# Nguyễn Văn Trân: rev_id = 1245671291, prediction = Stub
# Nguyễn Văn Xuân: rev_id = 1231154121, prediction = Stub
# Nguyễn Đức Chung: rev_id = 1248452284, prediction = Start
# Omar Prieto: rev_id = 1232134990, prediction = Start
# Pablo Acosta Ortiz: rev_id = 1243754078, prediction = C
# Renny Ottolina: rev_id = 1241457122, prediction = C
# Đinh Xuân Quảng: rev_id = 1238293364, prediction = B
# Đỗ Quang Giai: rev_id = 1229375855, prediction = C
# Abd Al-Rahman Ali Al-Jifri: rev_id = 1144463695, prediction = Start
# Abdul Qader Qahtan: rev_id = 1224446773, prediction = Start
# Abdul Wahab Al-Dailami: rev_id = 1189134411, prediction = Start
# Abdullah Noman: rev_id = 1248329006, prediction = Start
# Abdullatif Al-Sayed: rev_id = 1231304528, prediction = Start
# Abdulwahab al-Rawhani: rev_id = 1237331344, prediction = Start
# Aidarus al-Zoubaidi: rev_id = 1243417460, prediction = Start
# Ali Ahmad Nasser al-Dhahab: rev_id = 1106368440, prediction = Stub
# Ali Al Bukhaiti: rev_id = 1249864801, prediction = Stub
# Ali Taysir: rev_id = 1179127922, prediction = Stub
# Ameen Ali al-Akimi: rev_id = 1139612517, prediction = Stub
# Badreddin al-Houthi: rev_id = 1248072502, prediction = Stub
# Bruce Conde: rev_id = 1243942923, prediction = Start
# Bulelani Lobengula: rev_id = 1240505790, prediction = Start
# Chenhamo Chimutengwende: rev_id = 1246239471, prediction = Start
# Darlington Dzikamai Chigumbu: rev_id = 1217727776, prediction = Stub
# Faraj Salmin Al-Bahsani: rev_id = 1216872257, prediction = Stub
# Flora Buka: rev_id = 1235342444, prediction = Stub
# Francis Kapyanga: rev_id = 1241327476, prediction = Start
# Gift Banda: rev_id = 1227050005, prediction = Stub
# Hashid Abdullah al-Ahmar: rev_id = 1247681421, prediction = Stub
# Himyar Abdullah al-Ahmar: rev_id = 1247681426, prediction = Stub
# Hooria Mashhour: rev_id = 1241264144, prediction = C
# Hussein Khairan: rev_id = 1242390966, prediction = Start
# Ibrahim Bin Ali Al Wazeer: rev_id = 1144463479, prediction = Start
# James Chikerema: rev_id = 1247967827, prediction = C
# Joseph Makamba Busha: rev_id = 1215996308, prediction = Start
# Lily Monze: rev_id = 1245511378, prediction = Start
# Mohamed al-Atifi: rev_id = 1243159603, prediction = Start
# Mohammed Ali Al-Maqdashi: rev_id = 1228062555, prediction = Stub
# Mohammed Lutf al-Iryani: rev_id = 1219000221, prediction = Stub
# Mohammed al-Sabry: rev_id = 1232803611, prediction = Stub
# Muhammad Musa al-Amri: rev_id = 1144463258, prediction = C
# Muhammad bin Yahya bin Muhammad: rev_id = 1231305316, prediction = Stub
# Olipa Phiri: rev_id = 1180049589, prediction = Stub
# Paul Chimedza: rev_id = 1226620788, prediction = Stub
# Phan Anh: rev_id = 1224595790, prediction = Stub
# Sagheer Hamoud Aziz: rev_id = 1247681445, prediction = C
# Sam Yahya Al-Ahmar: rev_id = 1247681434, prediction = Stub
# Sultan al-Barakani: rev_id = 1246507826, prediction = Stub
# Talal Aklan: rev_id = 1242218278, prediction = Stub
# Tran Minh Tiet: rev_id = 1225066058, prediction = C
# Trương Đình Dzu: rev_id = 1220804010, prediction = GA
# Trần Quốc Vượng (politician): rev_id = 1237490552, prediction = C
# Trần Văn Hữu: rev_id = 1244544286, prediction = C
# Tạ Quang Bửu: rev_id = 1224595798, prediction = Stub
# Võ Văn Thưởng: rev_id = 1241845313, prediction = GA
# Yahya Mohamed Abdullah Saleh: rev_id = 1223542345, prediction = Stub
# Yahya Muhammad Hamid ed-Din: rev_id = 1249145023, prediction = C
# Yasser Al-Awadi: rev_id = 1129096674, prediction = Stub
# Abel Muzorewa: rev_id = 1246262690, prediction = C
# Aguy Georgias: rev_id = 1233377690, prediction = Start
# Alfred Makwarimba: rev_id = 1092395186, prediction = Stub
# Andre Sothern Holland: rev_id = 1203015285, prediction = Start
# Anxious Masuka: rev_id = 1247106176, prediction = Stub
# Bekithemba Mpofu: rev_id = 1085044064, prediction = Stub
# Bright Matonga: rev_id = 1036801272, prediction = Stub
# Byron Hove: rev_id = 1226322417, prediction = Stub
# Daniel Shumba: rev_id = 1154573139, prediction = Start
# Earnest Mudzengi: rev_id = 1246271197, prediction = Start
# Edwin Mushoriwa: rev_id = 1246239657, prediction = Stub
# Ellen Gwaradzimba: rev_id = 1246241932, prediction = Stub
# Elliot Manyika: rev_id = 1246001588, prediction = Start
# Engelbert Rugeje: rev_id = 1221940918, prediction = C
# Fletcher Dulini Ncube: rev_id = 1236276553, prediction = Start
# George Chiweshe: rev_id = 1237333574, prediction = Start
# George Nyandoro: rev_id = 1143871016, prediction = Start
# Gundwane Ndiweni: rev_id = 1223100611, prediction = Start
# Guy Clutton-Brock: rev_id = 1233375199, prediction = Start
# Isaac Matongo: rev_id = 1246276309, prediction = Stub
# Jabulani Dube: rev_id = 1084850581, prediction = Stub
# Jane Ngwenya: rev_id = 1199625809, prediction = Start
# Jevan Maseko: rev_id = 1084850620, prediction = Stub
# Josiah Zion Gumede: rev_id = 1230504811, prediction = Start
# Ken Flower: rev_id = 1246135863, prediction = Start
# Khayisa Ndiweni: rev_id = 1226322430, prediction = Start
# Kisinoti Mukwazhe: rev_id = 1108499694, prediction = Stub
# Linda Masarira: rev_id = 1177290618, prediction = C
# Lovemore Madhuku: rev_id = 1138179170, prediction = C
# Lovemore Matombo: rev_id = 1105192324, prediction = Stub
# Margaret Dongo: rev_id = 1201585392, prediction = C
# Maurice Nyagumbo: rev_id = 1225102400, prediction = Start
# Max Mnkandla: rev_id = 1007344798, prediction = Stub
# Mugabe family: rev_id = 1245786617, prediction = Start
# Munacho Mutezo: rev_id = 1112725980, prediction = Start
# Nhlanhlayamangwe Felix Ndiweni: rev_id = 1193170496, prediction = C
# Obedingwa Mguni: rev_id = 1247645001, prediction = Start
# Owen Ncube: rev_id = 1246242012, prediction = Start
# Phillip Chiyangwa: rev_id = 1204162245, prediction = C
# Prag Lalloo Naran: rev_id = 1170189291, prediction = C
# Promise Mkwananzi: rev_id = 1246747822, prediction = Start
# Ruth Chinamano: rev_id = 1233377754, prediction = Start
# Sarah Mahoka: rev_id = 1246239576, prediction = Stub
# Scot Sakupwanya: rev_id = 1242611251, prediction = Stub
# Sekai Nzenza: rev_id = 1241843269, prediction = Start
# Sithembile Gumbo: rev_id = 1246239507, prediction = Stub
# Tinos Rusere: rev_id = 1236282175, prediction = Start
# Tonderai Kasu: rev_id = 1231961724, prediction = C
# Washington Malianga: rev_id = 1064532257, prediction = Stub
# Wilson Khumbula: rev_id = 1246239559, prediction = C
# Denis Walker: rev_id = 1247902630, prediction = C
# Gift Tandare: rev_id = 1235705451, prediction = Stub
# Herbert Ushewokunze: rev_id = 959111842, prediction = Stub
# Josiah Tongogara: rev_id = 1203429435, prediction = C
# Langton Towungana: rev_id = 1246280093, prediction = Stub
# Leopold Takawira: rev_id = 1236900271, prediction = Start
# Maxwell Zeb Shumba: rev_id = 1246242430, prediction = Start
# Nkululeko Mkastos Sibanda: rev_id = 1243016866, prediction = Start
# Rekayi Tangwena: rev_id = 1236117496, prediction = Stub
# Sengezo Tshabangu: rev_id = 1228478288, prediction = Start
# Temba Mliswa: rev_id = 1246241769, prediction = Start

# %% [markdown]
# # Merge Data for Analysis
#
# This block of code loads the geography data and population data, combining them into the following files: 'politicians_by_country_no_ARTQUAL.csv' and 'wp_countries-no_match.txt'
#
# - 'politicians_by_country_no_ARTQUAL.csv' is an intermediary file that will be later merged with article quality data (from the ORES tool predictions) to be included int the analysis.
#
# - 'wp_countries-no_match.txt' is a final file that contains the list of countries not represented in the source data of politicians with wikipedia articles. However, that does not mean these countries do not have politicians with wikipedia articles.
#
# Countries with less than 1 million inhabitants will be excluded from the analysis, due to the data's tendency to mark these countries with a population of 0.
#
# The following code has been edited by a text-generator.
#
# ChatGPT prompt:
# - "Please load the population and geography data and create a function in python that will merge the two based on country. Then, identify the unmatched countries and output them in a text file"

# %%
# Load the population and geography data, return as a pandas DataFrame
def load_geography_population(file_path):
    geography_data = []
    no_population_countries = []
    current_region = None
    
    with open(file_path, mode='r') as file:
        reader = csv.reader(file)
        next(reader)  # Skip the header
        
        for row in reader:
            # Ensure there are exactly two columns and both are non-empty
            if len(row) != 2 or not row[0].strip() or not row[1].strip():
                print(f"Incomplete or missing data in row: {row}")
                continue
            
            name, population = row[0].strip(), row[1].strip()
            
            # If name is in all caps, it's a region
            if name.isupper():
                current_region = name
            else:
                # Check if population is empty or zero
                try:
                    population = float(population)
                except ValueError:
                    population = 0  # If the population is not a number, treat it as 0

                if population == 0:
                    no_population_countries.append(name)
                
                # Add the data to the list
                geography_data.append({
                    'country': name,
                    'region': current_region,
                    'population': population
                })
    
    # Convert to pandas DataFrame
    df = pd.DataFrame(geography_data)
    
    # Print first 5 rows
    print(df.head())
    print("The following countries have less than 1 million inhabitants,\n and will be excluded from the analysis:", no_population_countries)
    return df, no_population_countries

# Load the politicians_by_country CSV data
def load_politicians_data(file_path):
    politicians_df = pd.read_csv(file_path)
    return politicians_df

# Merge the two datasets and identify unmatched countries
def merge_datasets(geo_df, politicians_df, output_csv, no_match_txt):
    # Merge the two dataframes on 'country'
    merged_df = pd.merge(politicians_df, geo_df, how='outer', on='country', indicator=True)
    
    # Identify countries with no match in the geography data
    no_match_countries = merged_df[merged_df['_merge'] != 'both']['country'].dropna().unique()
    
    # Write no match countries to a text file
    with open(no_match_txt, 'w') as file:
        for country in no_match_countries:
            file.write(f"{country}\n")
    
    # Filter out the rows with unmatched countries and keep only successful merges
    # matched_df = merged_df[merged_df['_merge'] == 'both'].drop(columns=['_merge'])
    matched_df = merged_df[merged_df['_merge'] == 'both'].drop(columns=['_merge', 'url'])
    
    # Save the merged dataset to a CSV file
    matched_df.to_csv(output_csv, index=False)

    return matched_df

# File paths
geo_pop_file = 'population_by_country_AUG.2024.csv'  # The first CSV file
politicians_file = 'politicians_by_country_AUG.2024.csv'  # The second CSV file
output_csv = 'politicians_by_country_no_ARTQUAL.csv'
no_match_txt = 'wp_countries-no_match.txt'

# Load the data
geo_pop_data, no_population_countries = load_geography_population(geo_pop_file)
politicians_df = load_politicians_data(politicians_file)

# Merge datasets and handle unmatched countries
merged_data = merge_datasets(geo_pop_data, politicians_df, output_csv, no_match_txt)

print(f"Merged data has been written to {output_csv}")
# Out:
#    country           region  population
# 0  Algeria  NORTHERN AFRICA        46.8
# 1    Egypt  NORTHERN AFRICA       105.2
# 2    Libya  NORTHERN AFRICA         6.9
# 3  Morocco  NORTHERN AFRICA        37.0
# 4    Sudan  NORTHERN AFRICA        48.1
# The following countries have less than 1 million inhabitants,
#  and will be excluded from the analysis: ['Liechtenstein', 'Monaco', 'San Marino', 'Nauru', 'Palau', 'Tuvalu']
# Merged data has been written to politicians_by_country_no_ARTQUAL.csv

# %% [markdown]
# # Create Final File for Data Analysis
#
# This block of code creates a final file titled 'wp_politicians_by_country.csv' with six columns:
# - country
# - region
# - population
# - article title
# - revision ID
# - article quality
#
# It also outputs a list of the article names from the source dataset with no revision IDs or predictions, as these steps merge source data with processed data.

# %%
# Load the merged CSV file
csv_file = 'politicians_by_country_no_ARTQUAL.csv'
df = pd.read_csv(csv_file)

# Create new columns for 'revision_id' and 'article_quality' initialized with None
df['revision_id'] = None
df['article_quality'] = None

# Iterate through the DataFrame and populate the 'revision_id' and 'article_quality' columns
for index, row in df.iterrows():
    article_title = row['name'].strip()  # Assuming 'name' is the article title in CSV, remove leading/trailing spaces
    if article_title in predictions_dict:
        df.at[index, 'revision_id'] = predictions_dict[article_title]['rev_id']
        df.at[index, 'article_quality'] = predictions_dict[article_title]['prediction']
    else:
        print(f"No match found for {article_title} in the dictionary")

# Save the updated DataFrame to a new CSV file
output_csv = 'wp_politicians_by_country.csv'
df.to_csv(output_csv, index=False)

print(f"Updated data has been saved to {output_csv}")
# Out:
# No match found for Barbara Eibinger-Miedl in the dictionary
# No match found for Mehrali Gasimov in the dictionary
# No match found for Kyaw Myint in the dictionary
# No match found for André Ngongang Ouandji in the dictionary
# No match found for Tomás Pimentel in the dictionary
# No match found for Richard Sumah in the dictionary
# No match found for Carlos Pineda (politician) in the dictionary
# No match found for János Ghyczy in the dictionary
# No match found for Josip Ferfolja in the dictionary
# No match found for Nerio Giovanazzi in the dictionary
# No match found for Bernice Dahn in the dictionary
# No match found for Segun ''Aeroland'' Adewale in the dictionary
# No match found for Karol Dembovský in the dictionary
# No match found for Klemen Boštjančič in the dictionary
# No match found for Josip Ferfolja in the dictionary
# No match found for Bashir Bililiqo in the dictionary
# Updated data has been saved to wp_politicians_by_country.csv

# %% [markdown]
# # Edit Population Column
#
# Converts 'population' column in the 'wp_politicians_by_country.csv' file into millions for analysis.

# %%
# Load the dataset
file_name = 'wp_politicians_by_country.csv'
df = pd.read_csv(data_file)

# Update population values to be in millions
df['population'] = df['population'] * 1_000_000  # Convert population to millions

# Save the updated DataFrame back to the CSV file
df.to_csv(file_name, index=False)

# %% [markdown]
# # Add Columns for Aggregate Article Analysis
#
# The function create_cleaned_analysis creates two new columns, the number of articles per country, and the number of high quality articles per country.
#
# The following code has been edited by a text-generator.
#
# ChatGPT prompt:
# - "Please count the amount of article quality values containing "FA" and "GA", per country, and per region, and output the following as two new columns in the original dataset"

# %%
def create_cleaned_analysis(data_file, output_file='wp_cleaned_analysis.csv'):
    # Load the dataset
    df = pd.read_csv(data_file)

    # Calculate the number of high-quality articles (FA and GA) per country and region
    high_quality_count = df[df['article_quality'].isin(['FA', 'GA'])].groupby(['country', 'region']).size().reset_index(name='number_of_high_quality_articles')

    # Calculate the total number of articles per country and region
    article_count = df.groupby(['country', 'region']).size().reset_index(name='number_of_articles')

    # Create a DataFrame with all countries, regions, and their populations
    population_data = df[['country', 'region', 'population']].drop_duplicates()

    # Merge the high-quality article counts with the population data
    output_df = pd.merge(population_data, high_quality_count, on=['country', 'region'], how='left')

    # Merge the total article counts with the output DataFrame
    output_df = pd.merge(output_df, article_count, on=['country', 'region'], how='left')

    # Fill NaN values with 0 for countries without high-quality articles
    output_df['number_of_high_quality_articles'] = output_df['number_of_high_quality_articles'].fillna(0)

    # Display the output DataFrame
    display(output_df)

    # Save the output DataFrame to a new CSV file
    output_df.to_csv(output_file, index=False)

# Example usage
create_cleaned_analysis('wp_politicians_by_country.csv')
# Out:
#                  country           region  population  \
# 0            Afghanistan       SOUTH ASIA  42400000.0
# 1                Albania  SOUTHERN EUROPE   2700000.0
# 2                Algeria  NORTHERN AFRICA  46800000.0
# 3                 Angola    MIDDLE AFRICA  36700000.0
# 4    Antigua and Barbuda        CARIBBEAN    100000.0
# ..                   ...              ...         ...
# 161            Venezuela    SOUTH AMERICA  28800000.0
# 162              Vietnam   SOUTHEAST ASIA  98900000.0
# 163                Yemen     WESTERN ASIA  34400000.0
# 164               Zambia   EASTERN AFRICA  20200000.0
# 165             Zimbabwe   EASTERN AFRICA  16700000.0
#
#      number_of_high_quality_articles  number_of_articles
# 0                                3.0                  85
# 1                                7.0                  70
# 2                                1.0                  71
# 3                                2.0                  58
# 4                                0.0                  33
# ..                               ...                 ...
# 161                              1.0                  56
# 162                              2.0                  36
# 163                              0.0                  32
# 164                              0.0                   3
# 165                              0.0                  69
#
# [166 rows x 5 columns]

# %% [markdown]
# # Create Separate Files for Analysis by Country or by Region
#
# This function creates two separate intermediary files, one for generating tables analyzing articles and article quality per country, per capita, and one for generating tables analyzing articles and article quality per region, per capita.
#
# The following code has been edited by a text-generator.
#
# ChatGPT prompt:
# - "Please iterate the code to create two calculations, high-quality articles and total articles by country, and high quality articles and total articles by region."

# %%
def calculate_articles_per_capita(data_file, group_by='country', output_file_country='wp_cleaned_by_country.csv', output_file_region='wp_cleaned_by_region.csv'):
    # Load the cleaned analysis data
    df = pd.read_csv(data_file)

    # Replace any zero populations with NaN to avoid division errors
    df['population'] = df['population'].replace(0, np.nan)

    if group_by == 'country':
        # Group by country and calculate per capita metrics
        df_grouped = df.groupby('country').agg({
            'number_of_articles': 'sum',
            'number_of_high_quality_articles': 'sum',
            'population': 'mean'  # Assuming population doesn't change within a country
        }).reset_index()

        # Calculate articles per capita
        df_grouped['articles_per_capita'] = df_grouped['number_of_articles'] / df_grouped['population']

        # Calculate high-quality articles per capita
        df_grouped['high_quality_articles_per_capita'] = df_grouped['number_of_high_quality_articles'] / df_grouped['population']

        # Save the results to the country-based output file
        df_grouped.to_csv(output_file_country, index=False)

        # Display the updated DataFrame for country
        display(df_grouped.head())

    elif group_by == 'region':
        # Group by region and calculate per capita metrics
        df_grouped = df.groupby('region').agg({
            'number_of_articles': 'sum',
            'number_of_high_quality_articles': 'sum',
            'population': 'sum'  # Summing populations within a region
        }).reset_index()

        # Calculate articles per capita
        df_grouped['articles_per_capita'] = df_grouped['number_of_articles'] / df_grouped['population']

        # Calculate high-quality articles per capita
        df_grouped['high_quality_articles_per_capita'] = df_grouped['number_of_high_quality_articles'] / df_grouped['population']

        # Save the results to the region-based output file
        df_grouped.to_csv(output_file_region, index=False)

        # Display the updated DataFrame for region
        display(df_grouped.head())

# Example usage:
# To calculate per capita by country:
calculate_articles_per_capita('wp_cleaned_analysis.csv', group_by='country')

# To calculate per capita by region:
calculate_articles_per_capita('wp_cleaned_analysis.csv', group_by='region')
# Out:
#                country  number_of_articles  number_of_high_quality_articles  \
# 0          Afghanistan                  85                              3.0
# 1              Albania                  70                              7.0
# 2              Algeria                  71                              1.0
# 3               Angola                  58                              2.0
# 4  Antigua and Barbuda                  33                              0.0
#
#    population  articles_per_capita  high_quality_articles_per_capita
# 0  42400000.0             0.000002                      7.075472e-08
# 1   2700000.0             0.000026                      2.592593e-06
# 2  46800000.0             0.000002                      2.136752e-08
# 3  36700000.0             0.000002                      5.449591e-08
# 4    100000.0             0.000330                      0.000000e+00
#             region  number_of_articles  number_of_high_quality_articles  \
# 0        CARIBBEAN                 219                              9.0
# 1  CENTRAL AMERICA                 188                              9.0
# 2     CENTRAL ASIA                 106                              5.0
# 3        EAST ASIA                 152                              3.0
# 4   EASTERN AFRICA                 665                             17.0
#
#      population  articles_per_capita  high_quality_articles_per_capita
# 0  3.660000e+07         5.983607e-06                      2.459016e-07
# 1  5.130000e+07         3.664717e-06                      1.754386e-07
# 2  8.040000e+07         1.318408e-06                      6.218905e-08
# 3  1.562700e+09         9.726755e-08                      1.919754e-09
# 4  4.809000e+08         1.382824e-06                      3.535038e-08

# %% [markdown]
# # Generate and Embed Tables From Analysis
#
# The following block generates six tables:
#
# - Top 10 countries by coverage: The 10 countries with the highest total articles per capita (in descending order)
# - Bottom 10 countries by coverage: The 10 countries with the lowest total articles per capita (in ascending order)
# - Top 10 countries by high quality: The 10 countries with the highest high quality articles per capita (in descending order)
# - Bottom 10 countries by high quality: The 10 countries with the lowest high quality articles per capita (in ascending order)
# - Geographic regions by total coverage: A rank ordered list of geographic regions (in descending order) by total articles per capita.
# - Geographic regions by high quality coverage: Rank ordered list of geographic regions (in descending order) by high quality articles per capita.

# %%
def generate_tables(country_file='wp_cleaned_by_country.csv', region_file='wp_cleaned_by_region.csv'):
    # Load the country-level and region-level datasets
    df_country = pd.read_csv(country_file)
    df_region = pd.read_csv(region_file)

    # 1. Top 10 countries by total articles per capita (descending order)
    top_10_countries_by_coverage = df_country[['country', 'articles_per_capita']].sort_values(by='articles_per_capita', ascending=False).head(10)
    print("Top 10 countries by coverage:")
    display(top_10_countries_by_coverage)

    # 2. Bottom 10 countries by total articles per capita (ascending order)
    bottom_10_countries_by_coverage = df_country[['country', 'articles_per_capita']].sort_values(by='articles_per_capita', ascending=True).head(10)
    print("\nBottom 10 countries by coverage:")
    display(bottom_10_countries_by_coverage)

    # 3. Top 10 countries by high quality articles per capita (descending order)
    top_10_countries_by_high_quality = df_country[['country', 'high_quality_articles_per_capita']].sort_values(by='high_quality_articles_per_capita', ascending=False).head(10)
    print("\nTop 10 countries by high quality articles:")
    display(top_10_countries_by_high_quality)

    # 4. Bottom 10 countries by high quality articles per capita (ascending order)
    bottom_10_countries_by_high_quality = df_country[['country', 'high_quality_articles_per_capita']].sort_values(by='high_quality_articles_per_capita', ascending=True).head(10)
    print("\nBottom 10 countries by high quality articles:")
    display(bottom_10_countries_by_high_quality)

    # 5. Geographic regions by total coverage (articles per capita in descending order)
    regions_by_total_coverage = df_region[['region', 'articles_per_capita']].sort_values(by='articles_per_capita', ascending=False)
    print("\nGeographic regions by total coverage:")
    display(regions_by_total_coverage)

    # 6. Geographic regions by high quality articles per capita (descending order)
    regions_by_high_quality_coverage = df_region[['region', 'high_quality_articles_per_capita']].sort_values(by='high_quality_articles_per_capita', ascending=False)
    print("\nGeographic regions by high quality articles:")
    display(regions_by_high_quality_coverage)

# Example usage
generate_tables()
# Out:
# Top 10 countries by coverage:
#                             country  articles_per_capita
# 4               Antigua and Barbuda             0.000330
# 51   Federated States of Micronesia             0.000140
# 93                 Marshall Islands             0.000130
# 149                           Tonga             0.000100
# 12                         Barbados             0.000083
# 125                      Seychelles             0.000060
# 98                       Montenegro             0.000060
# 17                           Bhutan             0.000055
# 90                         Maldives             0.000055
